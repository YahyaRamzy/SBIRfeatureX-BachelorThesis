# %%
import cv2
import numpy as np
import os
from keras.preprocessing.image import ImageDataGenerator
from keras.layers import Dense,Flatten,Conv2D,Activation,Dropout
from keras import backend as K
import keras
from keras.models import Sequential, Model
from keras.models import load_model
from keras.optimizers import SGD
from keras.callbacks import EarlyStopping,ModelCheckpoint
from keras.layers import MaxPool2D
import tensorflow as tf

# %%
train_path="E:/SBIR/Selected/train"
test_path="E:/SBIR/Selected/test"
class_names=os.listdir(train_path)
class_names_test=os.listdir(test_path)

# %%
train_datagen = ImageDataGenerator(zoom_range=0.15,width_shift_range=0.2,height_shift_range=0.2,shear_range=0.15,horizontal_flip=True)
test_datagen = ImageDataGenerator()

# %%
train_generator = train_datagen.flow_from_directory(train_path,target_size=(224, 224),batch_size=64,shuffle=True,class_mode='categorical')
test_generator = test_datagen.flow_from_directory(test_path,target_size=(224,224),batch_size=64,shuffle=False,class_mode='categorical')
# Out:
# Found 780 images belonging to 13 classes.
# Found 260 images belonging to 13 classes.

# %%
trdata = ImageDataGenerator()
traindata = trdata.flow_from_directory(directory="E:/SBIR/Selected/train",target_size=(224,224))
tsdata = ImageDataGenerator()
testdata = tsdata.flow_from_directory(directory="E:/SBIR/Selected/test", target_size=(224,224))
# Out:
# Found 780 images belonging to 13 classes.
# Found 260 images belonging to 13 classes.

# %%
from tensorflow.keras.applications.inception_v3 import InceptionV3

# %%
pre_trained_model = InceptionV3(input_shape = (224,224,3) , include_top = False , weights = 'imagenet' , classes='13')

# %%
for layer in pre_trained_model.layers:
        layer.trainable=False

# %%
pre_trained_model.summary()
# Out:
# Model: "inception_v3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_4 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv2d_283 (Conv2D)            (None, 111, 111, 32  864         ['input_4[0][0]']
#                                 )
#
#  batch_normalization_286 (Batch  (None, 111, 111, 32  96         ['conv2d_283[0][0]']
#  Normalization)                 )
#
#  activation_282 (Activation)    (None, 111, 111, 32  0           ['batch_normalization_286[0][0]']
#                                 )
#
#  conv2d_284 (Conv2D)            (None, 109, 109, 32  9216        ['activation_282[0][0]']
#                                 )
#
#  batch_normalization_287 (Batch  (None, 109, 109, 32  96         ['conv2d_284[0][0]']
#  Normalization)                 )
#
#  activation_283 (Activation)    (None, 109, 109, 32  0           ['batch_normalization_287[0][0]']
#                                 )
#
#  conv2d_285 (Conv2D)            (None, 109, 109, 64  18432       ['activation_283[0][0]']
#                                 )
#
#  batch_normalization_288 (Batch  (None, 109, 109, 64  192        ['conv2d_285[0][0]']
#  Normalization)                 )
#
#  activation_284 (Activation)    (None, 109, 109, 64  0           ['batch_normalization_288[0][0]']
#                                 )
#
#  max_pooling2d_13 (MaxPooling2D  (None, 54, 54, 64)  0           ['activation_284[0][0]']
#  )
#
#  conv2d_286 (Conv2D)            (None, 54, 54, 80)   5120        ['max_pooling2d_13[0][0]']
#
#  batch_normalization_289 (Batch  (None, 54, 54, 80)  240         ['conv2d_286[0][0]']
#  Normalization)
#
#  activation_285 (Activation)    (None, 54, 54, 80)   0           ['batch_normalization_289[0][0]']
#
#  conv2d_287 (Conv2D)            (None, 52, 52, 192)  138240      ['activation_285[0][0]']
#
#  batch_normalization_290 (Batch  (None, 52, 52, 192)  576        ['conv2d_287[0][0]']
#  Normalization)
#
#  activation_286 (Activation)    (None, 52, 52, 192)  0           ['batch_normalization_290[0][0]']
#
#  max_pooling2d_14 (MaxPooling2D  (None, 25, 25, 192)  0          ['activation_286[0][0]']
#  )
#
#  conv2d_291 (Conv2D)            (None, 25, 25, 64)   12288       ['max_pooling2d_14[0][0]']
#
#  batch_normalization_294 (Batch  (None, 25, 25, 64)  192         ['conv2d_291[0][0]']
#  Normalization)
#
#  activation_290 (Activation)    (None, 25, 25, 64)   0           ['batch_normalization_294[0][0]']
#
#  conv2d_289 (Conv2D)            (None, 25, 25, 48)   9216        ['max_pooling2d_14[0][0]']
#
#  conv2d_292 (Conv2D)            (None, 25, 25, 96)   55296       ['activation_290[0][0]']
#
#  batch_normalization_292 (Batch  (None, 25, 25, 48)  144         ['conv2d_289[0][0]']
#  Normalization)
#
#  batch_normalization_295 (Batch  (None, 25, 25, 96)  288         ['conv2d_292[0][0]']
#  Normalization)
#
#  activation_288 (Activation)    (None, 25, 25, 48)   0           ['batch_normalization_292[0][0]']
#
#  activation_291 (Activation)    (None, 25, 25, 96)   0           ['batch_normalization_295[0][0]']
#
#  average_pooling2d_27 (AverageP  (None, 25, 25, 192)  0          ['max_pooling2d_14[0][0]']
#  ooling2D)
#
#  conv2d_288 (Conv2D)            (None, 25, 25, 64)   12288       ['max_pooling2d_14[0][0]']
#
#  conv2d_290 (Conv2D)            (None, 25, 25, 64)   76800       ['activation_288[0][0]']
#
#  conv2d_293 (Conv2D)            (None, 25, 25, 96)   82944       ['activation_291[0][0]']
#
#  conv2d_294 (Conv2D)            (None, 25, 25, 32)   6144        ['average_pooling2d_27[0][0]']
#
#  batch_normalization_291 (Batch  (None, 25, 25, 64)  192         ['conv2d_288[0][0]']
#  Normalization)
#
#  batch_normalization_293 (Batch  (None, 25, 25, 64)  192         ['conv2d_290[0][0]']
#  Normalization)
#
#  batch_normalization_296 (Batch  (None, 25, 25, 96)  288         ['conv2d_293[0][0]']
#  Normalization)
#
#  batch_normalization_297 (Batch  (None, 25, 25, 32)  96          ['conv2d_294[0][0]']
#  Normalization)
#
#  activation_287 (Activation)    (None, 25, 25, 64)   0           ['batch_normalization_291[0][0]']
#
#  activation_289 (Activation)    (None, 25, 25, 64)   0           ['batch_normalization_293[0][0]']
#
#  activation_292 (Activation)    (None, 25, 25, 96)   0           ['batch_normalization_296[0][0]']
#
#  activation_293 (Activation)    (None, 25, 25, 32)   0           ['batch_normalization_297[0][0]']
#
#  mixed0 (Concatenate)           (None, 25, 25, 256)  0           ['activation_287[0][0]',
#                                                                   'activation_289[0][0]',
#                                                                   'activation_292[0][0]',
#                                                                   'activation_293[0][0]']
#
#  conv2d_298 (Conv2D)            (None, 25, 25, 64)   16384       ['mixed0[0][0]']
#
#  batch_normalization_301 (Batch  (None, 25, 25, 64)  192         ['conv2d_298[0][0]']
#  Normalization)
#
#  activation_297 (Activation)    (None, 25, 25, 64)   0           ['batch_normalization_301[0][0]']
#
#  conv2d_296 (Conv2D)            (None, 25, 25, 48)   12288       ['mixed0[0][0]']
#
#  conv2d_299 (Conv2D)            (None, 25, 25, 96)   55296       ['activation_297[0][0]']
#
#  batch_normalization_299 (Batch  (None, 25, 25, 48)  144         ['conv2d_296[0][0]']
#  Normalization)
#
#  batch_normalization_302 (Batch  (None, 25, 25, 96)  288         ['conv2d_299[0][0]']
#  Normalization)
#
#  activation_295 (Activation)    (None, 25, 25, 48)   0           ['batch_normalization_299[0][0]']
#
#  activation_298 (Activation)    (None, 25, 25, 96)   0           ['batch_normalization_302[0][0]']
#
#  average_pooling2d_28 (AverageP  (None, 25, 25, 256)  0          ['mixed0[0][0]']
#  ooling2D)
#
#  conv2d_295 (Conv2D)            (None, 25, 25, 64)   16384       ['mixed0[0][0]']
#
#  conv2d_297 (Conv2D)            (None, 25, 25, 64)   76800       ['activation_295[0][0]']
#
#  conv2d_300 (Conv2D)            (None, 25, 25, 96)   82944       ['activation_298[0][0]']
#
#  conv2d_301 (Conv2D)            (None, 25, 25, 64)   16384       ['average_pooling2d_28[0][0]']
#
#  batch_normalization_298 (Batch  (None, 25, 25, 64)  192         ['conv2d_295[0][0]']
#  Normalization)
#
#  batch_normalization_300 (Batch  (None, 25, 25, 64)  192         ['conv2d_297[0][0]']
#  Normalization)
#
#  batch_normalization_303 (Batch  (None, 25, 25, 96)  288         ['conv2d_300[0][0]']
#  Normalization)
#
#  batch_normalization_304 (Batch  (None, 25, 25, 64)  192         ['conv2d_301[0][0]']
#  Normalization)
#
#  activation_294 (Activation)    (None, 25, 25, 64)   0           ['batch_normalization_298[0][0]']
#
#  activation_296 (Activation)    (None, 25, 25, 64)   0           ['batch_normalization_300[0][0]']
#
#  activation_299 (Activation)    (None, 25, 25, 96)   0           ['batch_normalization_303[0][0]']
#
#  activation_300 (Activation)    (None, 25, 25, 64)   0           ['batch_normalization_304[0][0]']
#
#  mixed1 (Concatenate)           (None, 25, 25, 288)  0           ['activation_294[0][0]',
#                                                                   'activation_296[0][0]',
#                                                                   'activation_299[0][0]',
#                                                                   'activation_300[0][0]']
#
#  conv2d_305 (Conv2D)            (None, 25, 25, 64)   18432       ['mixed1[0][0]']
#
#  batch_normalization_308 (Batch  (None, 25, 25, 64)  192         ['conv2d_305[0][0]']
#  Normalization)
#
#  activation_304 (Activation)    (None, 25, 25, 64)   0           ['batch_normalization_308[0][0]']
#
#  conv2d_303 (Conv2D)            (None, 25, 25, 48)   13824       ['mixed1[0][0]']
#
#  conv2d_306 (Conv2D)            (None, 25, 25, 96)   55296       ['activation_304[0][0]']
#
#  batch_normalization_306 (Batch  (None, 25, 25, 48)  144         ['conv2d_303[0][0]']
#  Normalization)
#
#  batch_normalization_309 (Batch  (None, 25, 25, 96)  288         ['conv2d_306[0][0]']
#  Normalization)
#
#  activation_302 (Activation)    (None, 25, 25, 48)   0           ['batch_normalization_306[0][0]']
#
#  activation_305 (Activation)    (None, 25, 25, 96)   0           ['batch_normalization_309[0][0]']
#
#  average_pooling2d_29 (AverageP  (None, 25, 25, 288)  0          ['mixed1[0][0]']
#  ooling2D)
#
#  conv2d_302 (Conv2D)            (None, 25, 25, 64)   18432       ['mixed1[0][0]']
#
#  conv2d_304 (Conv2D)            (None, 25, 25, 64)   76800       ['activation_302[0][0]']
#
#  conv2d_307 (Conv2D)            (None, 25, 25, 96)   82944       ['activation_305[0][0]']
#
#  conv2d_308 (Conv2D)            (None, 25, 25, 64)   18432       ['average_pooling2d_29[0][0]']
#
#  batch_normalization_305 (Batch  (None, 25, 25, 64)  192         ['conv2d_302[0][0]']
#  Normalization)
#
#  batch_normalization_307 (Batch  (None, 25, 25, 64)  192         ['conv2d_304[0][0]']
#  Normalization)
#
#  batch_normalization_310 (Batch  (None, 25, 25, 96)  288         ['conv2d_307[0][0]']
#  Normalization)
#
#  batch_normalization_311 (Batch  (None, 25, 25, 64)  192         ['conv2d_308[0][0]']
#  Normalization)
#
#  activation_301 (Activation)    (None, 25, 25, 64)   0           ['batch_normalization_305[0][0]']
#
#  activation_303 (Activation)    (None, 25, 25, 64)   0           ['batch_normalization_307[0][0]']
#
#  activation_306 (Activation)    (None, 25, 25, 96)   0           ['batch_normalization_310[0][0]']
#
#  activation_307 (Activation)    (None, 25, 25, 64)   0           ['batch_normalization_311[0][0]']
#
#  mixed2 (Concatenate)           (None, 25, 25, 288)  0           ['activation_301[0][0]',
#                                                                   'activation_303[0][0]',
#                                                                   'activation_306[0][0]',
#                                                                   'activation_307[0][0]']
#
#  conv2d_310 (Conv2D)            (None, 25, 25, 64)   18432       ['mixed2[0][0]']
#
#  batch_normalization_313 (Batch  (None, 25, 25, 64)  192         ['conv2d_310[0][0]']
#  Normalization)
#
#  activation_309 (Activation)    (None, 25, 25, 64)   0           ['batch_normalization_313[0][0]']
#
#  conv2d_311 (Conv2D)            (None, 25, 25, 96)   55296       ['activation_309[0][0]']
#
#  batch_normalization_314 (Batch  (None, 25, 25, 96)  288         ['conv2d_311[0][0]']
#  Normalization)
#
#  activation_310 (Activation)    (None, 25, 25, 96)   0           ['batch_normalization_314[0][0]']
#
#  conv2d_309 (Conv2D)            (None, 12, 12, 384)  995328      ['mixed2[0][0]']
#
#  conv2d_312 (Conv2D)            (None, 12, 12, 96)   82944       ['activation_310[0][0]']
#
#  batch_normalization_312 (Batch  (None, 12, 12, 384)  1152       ['conv2d_309[0][0]']
#  Normalization)
#
#  batch_normalization_315 (Batch  (None, 12, 12, 96)  288         ['conv2d_312[0][0]']
#  Normalization)
#
#  activation_308 (Activation)    (None, 12, 12, 384)  0           ['batch_normalization_312[0][0]']
#
#  activation_311 (Activation)    (None, 12, 12, 96)   0           ['batch_normalization_315[0][0]']
#
#  max_pooling2d_15 (MaxPooling2D  (None, 12, 12, 288)  0          ['mixed2[0][0]']
#  )
#
#  mixed3 (Concatenate)           (None, 12, 12, 768)  0           ['activation_308[0][0]',
#                                                                   'activation_311[0][0]',
#                                                                   'max_pooling2d_15[0][0]']
#
#  conv2d_317 (Conv2D)            (None, 12, 12, 128)  98304       ['mixed3[0][0]']
#
#  batch_normalization_320 (Batch  (None, 12, 12, 128)  384        ['conv2d_317[0][0]']
#  Normalization)
#
#  activation_316 (Activation)    (None, 12, 12, 128)  0           ['batch_normalization_320[0][0]']
#
#  conv2d_318 (Conv2D)            (None, 12, 12, 128)  114688      ['activation_316[0][0]']
#
#  batch_normalization_321 (Batch  (None, 12, 12, 128)  384        ['conv2d_318[0][0]']
#  Normalization)
#
#  activation_317 (Activation)    (None, 12, 12, 128)  0           ['batch_normalization_321[0][0]']
#
#  conv2d_314 (Conv2D)            (None, 12, 12, 128)  98304       ['mixed3[0][0]']
#
#  conv2d_319 (Conv2D)            (None, 12, 12, 128)  114688      ['activation_317[0][0]']
#
#  batch_normalization_317 (Batch  (None, 12, 12, 128)  384        ['conv2d_314[0][0]']
#  Normalization)
#
#  batch_normalization_322 (Batch  (None, 12, 12, 128)  384        ['conv2d_319[0][0]']
#  Normalization)
#
#  activation_313 (Activation)    (None, 12, 12, 128)  0           ['batch_normalization_317[0][0]']
#
#  activation_318 (Activation)    (None, 12, 12, 128)  0           ['batch_normalization_322[0][0]']
#
#  conv2d_315 (Conv2D)            (None, 12, 12, 128)  114688      ['activation_313[0][0]']
#
#  conv2d_320 (Conv2D)            (None, 12, 12, 128)  114688      ['activation_318[0][0]']
#
#  batch_normalization_318 (Batch  (None, 12, 12, 128)  384        ['conv2d_315[0][0]']
#  Normalization)
#
#  batch_normalization_323 (Batch  (None, 12, 12, 128)  384        ['conv2d_320[0][0]']
#  Normalization)
#
#  activation_314 (Activation)    (None, 12, 12, 128)  0           ['batch_normalization_318[0][0]']
#
#  activation_319 (Activation)    (None, 12, 12, 128)  0           ['batch_normalization_323[0][0]']
#
#  average_pooling2d_30 (AverageP  (None, 12, 12, 768)  0          ['mixed3[0][0]']
#  ooling2D)
#
#  conv2d_313 (Conv2D)            (None, 12, 12, 192)  147456      ['mixed3[0][0]']
#
#  conv2d_316 (Conv2D)            (None, 12, 12, 192)  172032      ['activation_314[0][0]']
#
#  conv2d_321 (Conv2D)            (None, 12, 12, 192)  172032      ['activation_319[0][0]']
#
#  conv2d_322 (Conv2D)            (None, 12, 12, 192)  147456      ['average_pooling2d_30[0][0]']
#
#  batch_normalization_316 (Batch  (None, 12, 12, 192)  576        ['conv2d_313[0][0]']
#  Normalization)
#
#  batch_normalization_319 (Batch  (None, 12, 12, 192)  576        ['conv2d_316[0][0]']
#  Normalization)
#
#  batch_normalization_324 (Batch  (None, 12, 12, 192)  576        ['conv2d_321[0][0]']
#  Normalization)
#
#  batch_normalization_325 (Batch  (None, 12, 12, 192)  576        ['conv2d_322[0][0]']
#  Normalization)
#
#  activation_312 (Activation)    (None, 12, 12, 192)  0           ['batch_normalization_316[0][0]']
#
#  activation_315 (Activation)    (None, 12, 12, 192)  0           ['batch_normalization_319[0][0]']
#
#  activation_320 (Activation)    (None, 12, 12, 192)  0           ['batch_normalization_324[0][0]']
#
#  activation_321 (Activation)    (None, 12, 12, 192)  0           ['batch_normalization_325[0][0]']
#
#  mixed4 (Concatenate)           (None, 12, 12, 768)  0           ['activation_312[0][0]',
#                                                                   'activation_315[0][0]',
#                                                                   'activation_320[0][0]',
#                                                                   'activation_321[0][0]']
#
#  conv2d_327 (Conv2D)            (None, 12, 12, 160)  122880      ['mixed4[0][0]']
#
#  batch_normalization_330 (Batch  (None, 12, 12, 160)  480        ['conv2d_327[0][0]']
#  Normalization)
#
#  activation_326 (Activation)    (None, 12, 12, 160)  0           ['batch_normalization_330[0][0]']
#
#  conv2d_328 (Conv2D)            (None, 12, 12, 160)  179200      ['activation_326[0][0]']
#
#  batch_normalization_331 (Batch  (None, 12, 12, 160)  480        ['conv2d_328[0][0]']
#  Normalization)
#
#  activation_327 (Activation)    (None, 12, 12, 160)  0           ['batch_normalization_331[0][0]']
#
#  conv2d_324 (Conv2D)            (None, 12, 12, 160)  122880      ['mixed4[0][0]']
#
#  conv2d_329 (Conv2D)            (None, 12, 12, 160)  179200      ['activation_327[0][0]']
#
#  batch_normalization_327 (Batch  (None, 12, 12, 160)  480        ['conv2d_324[0][0]']
#  Normalization)
#
#  batch_normalization_332 (Batch  (None, 12, 12, 160)  480        ['conv2d_329[0][0]']
#  Normalization)
#
#  activation_323 (Activation)    (None, 12, 12, 160)  0           ['batch_normalization_327[0][0]']
#
#  activation_328 (Activation)    (None, 12, 12, 160)  0           ['batch_normalization_332[0][0]']
#
#  conv2d_325 (Conv2D)            (None, 12, 12, 160)  179200      ['activation_323[0][0]']
#
#  conv2d_330 (Conv2D)            (None, 12, 12, 160)  179200      ['activation_328[0][0]']
#
#  batch_normalization_328 (Batch  (None, 12, 12, 160)  480        ['conv2d_325[0][0]']
#  Normalization)
#
#  batch_normalization_333 (Batch  (None, 12, 12, 160)  480        ['conv2d_330[0][0]']
#  Normalization)
#
#  activation_324 (Activation)    (None, 12, 12, 160)  0           ['batch_normalization_328[0][0]']
#
#  activation_329 (Activation)    (None, 12, 12, 160)  0           ['batch_normalization_333[0][0]']
#
#  average_pooling2d_31 (AverageP  (None, 12, 12, 768)  0          ['mixed4[0][0]']
#  ooling2D)
#
#  conv2d_323 (Conv2D)            (None, 12, 12, 192)  147456      ['mixed4[0][0]']
#
#  conv2d_326 (Conv2D)            (None, 12, 12, 192)  215040      ['activation_324[0][0]']
#
#  conv2d_331 (Conv2D)            (None, 12, 12, 192)  215040      ['activation_329[0][0]']
#
#  conv2d_332 (Conv2D)            (None, 12, 12, 192)  147456      ['average_pooling2d_31[0][0]']
#
#  batch_normalization_326 (Batch  (None, 12, 12, 192)  576        ['conv2d_323[0][0]']
#  Normalization)
#
#  batch_normalization_329 (Batch  (None, 12, 12, 192)  576        ['conv2d_326[0][0]']
#  Normalization)
#
#  batch_normalization_334 (Batch  (None, 12, 12, 192)  576        ['conv2d_331[0][0]']
#  Normalization)
#
#  batch_normalization_335 (Batch  (None, 12, 12, 192)  576        ['conv2d_332[0][0]']
#  Normalization)
#
#  activation_322 (Activation)    (None, 12, 12, 192)  0           ['batch_normalization_326[0][0]']
#
#  activation_325 (Activation)    (None, 12, 12, 192)  0           ['batch_normalization_329[0][0]']
#
#  activation_330 (Activation)    (None, 12, 12, 192)  0           ['batch_normalization_334[0][0]']
#
#  activation_331 (Activation)    (None, 12, 12, 192)  0           ['batch_normalization_335[0][0]']
#
#  mixed5 (Concatenate)           (None, 12, 12, 768)  0           ['activation_322[0][0]',
#                                                                   'activation_325[0][0]',
#                                                                   'activation_330[0][0]',
#                                                                   'activation_331[0][0]']
#
#  conv2d_337 (Conv2D)            (None, 12, 12, 160)  122880      ['mixed5[0][0]']
#
#  batch_normalization_340 (Batch  (None, 12, 12, 160)  480        ['conv2d_337[0][0]']
#  Normalization)
#
#  activation_336 (Activation)    (None, 12, 12, 160)  0           ['batch_normalization_340[0][0]']
#
#  conv2d_338 (Conv2D)            (None, 12, 12, 160)  179200      ['activation_336[0][0]']
#
#  batch_normalization_341 (Batch  (None, 12, 12, 160)  480        ['conv2d_338[0][0]']
#  Normalization)
#
#  activation_337 (Activation)    (None, 12, 12, 160)  0           ['batch_normalization_341[0][0]']
#
#  conv2d_334 (Conv2D)            (None, 12, 12, 160)  122880      ['mixed5[0][0]']
#
#  conv2d_339 (Conv2D)            (None, 12, 12, 160)  179200      ['activation_337[0][0]']
#
#  batch_normalization_337 (Batch  (None, 12, 12, 160)  480        ['conv2d_334[0][0]']
#  Normalization)
#
#  batch_normalization_342 (Batch  (None, 12, 12, 160)  480        ['conv2d_339[0][0]']
#  Normalization)
#
#  activation_333 (Activation)    (None, 12, 12, 160)  0           ['batch_normalization_337[0][0]']
#
#  activation_338 (Activation)    (None, 12, 12, 160)  0           ['batch_normalization_342[0][0]']
#
#  conv2d_335 (Conv2D)            (None, 12, 12, 160)  179200      ['activation_333[0][0]']
#
#  conv2d_340 (Conv2D)            (None, 12, 12, 160)  179200      ['activation_338[0][0]']
#
#  batch_normalization_338 (Batch  (None, 12, 12, 160)  480        ['conv2d_335[0][0]']
#  Normalization)
#
#  batch_normalization_343 (Batch  (None, 12, 12, 160)  480        ['conv2d_340[0][0]']
#  Normalization)
#
#  activation_334 (Activation)    (None, 12, 12, 160)  0           ['batch_normalization_338[0][0]']
#
#  activation_339 (Activation)    (None, 12, 12, 160)  0           ['batch_normalization_343[0][0]']
#
#  average_pooling2d_32 (AverageP  (None, 12, 12, 768)  0          ['mixed5[0][0]']
#  ooling2D)
#
#  conv2d_333 (Conv2D)            (None, 12, 12, 192)  147456      ['mixed5[0][0]']
#
#  conv2d_336 (Conv2D)            (None, 12, 12, 192)  215040      ['activation_334[0][0]']
#
#  conv2d_341 (Conv2D)            (None, 12, 12, 192)  215040      ['activation_339[0][0]']
#
#  conv2d_342 (Conv2D)            (None, 12, 12, 192)  147456      ['average_pooling2d_32[0][0]']
#
#  batch_normalization_336 (Batch  (None, 12, 12, 192)  576        ['conv2d_333[0][0]']
#  Normalization)
#
#  batch_normalization_339 (Batch  (None, 12, 12, 192)  576        ['conv2d_336[0][0]']
#  Normalization)
#
#  batch_normalization_344 (Batch  (None, 12, 12, 192)  576        ['conv2d_341[0][0]']
#  Normalization)
#
#  batch_normalization_345 (Batch  (None, 12, 12, 192)  576        ['conv2d_342[0][0]']
#  Normalization)
#
#  activation_332 (Activation)    (None, 12, 12, 192)  0           ['batch_normalization_336[0][0]']
#
#  activation_335 (Activation)    (None, 12, 12, 192)  0           ['batch_normalization_339[0][0]']
#
# ...
#  mixed8 (Concatenate)           (None, 5, 5, 1280)   0           ['activation_353[0][0]',
#                                                                   'activation_357[0][0]',
#                                                                   'max_pooling2d_16[0][0]']
#
#  conv2d_363 (Conv2D)            (None, 5, 5, 448)    573440      ['mixed8[0][0]']
#
#  batch_normalization_366 (Batch  (None, 5, 5, 448)   1344        ['conv2d_363[0][0]']
#  Normalization)
#
#  activation_362 (Activation)    (None, 5, 5, 448)    0           ['batch_normalization_366[0][0]']
#
#  conv2d_360 (Conv2D)            (None, 5, 5, 384)    491520      ['mixed8[0][0]']
#
#  conv2d_364 (Conv2D)            (None, 5, 5, 384)    1548288     ['activation_362[0][0]']
#
#  batch_normalization_363 (Batch  (None, 5, 5, 384)   1152        ['conv2d_360[0][0]']
#  Normalization)
#
#  batch_normalization_367 (Batch  (None, 5, 5, 384)   1152        ['conv2d_364[0][0]']
#  Normalization)
#
#  activation_359 (Activation)    (None, 5, 5, 384)    0           ['batch_normalization_363[0][0]']
#
#  activation_363 (Activation)    (None, 5, 5, 384)    0           ['batch_normalization_367[0][0]']
#
#  conv2d_361 (Conv2D)            (None, 5, 5, 384)    442368      ['activation_359[0][0]']
#
#  conv2d_362 (Conv2D)            (None, 5, 5, 384)    442368      ['activation_359[0][0]']
#
#  conv2d_365 (Conv2D)            (None, 5, 5, 384)    442368      ['activation_363[0][0]']
#
#  conv2d_366 (Conv2D)            (None, 5, 5, 384)    442368      ['activation_363[0][0]']
#
#  average_pooling2d_34 (AverageP  (None, 5, 5, 1280)  0           ['mixed8[0][0]']
#  ooling2D)
#
#  conv2d_359 (Conv2D)            (None, 5, 5, 320)    409600      ['mixed8[0][0]']
#
#  batch_normalization_364 (Batch  (None, 5, 5, 384)   1152        ['conv2d_361[0][0]']
#  Normalization)
#
#  batch_normalization_365 (Batch  (None, 5, 5, 384)   1152        ['conv2d_362[0][0]']
#  Normalization)
#
#  batch_normalization_368 (Batch  (None, 5, 5, 384)   1152        ['conv2d_365[0][0]']
#  Normalization)
#
#  batch_normalization_369 (Batch  (None, 5, 5, 384)   1152        ['conv2d_366[0][0]']
#  Normalization)
#
#  conv2d_367 (Conv2D)            (None, 5, 5, 192)    245760      ['average_pooling2d_34[0][0]']
#
#  batch_normalization_362 (Batch  (None, 5, 5, 320)   960         ['conv2d_359[0][0]']
#  Normalization)
#
#  activation_360 (Activation)    (None, 5, 5, 384)    0           ['batch_normalization_364[0][0]']
#
#  activation_361 (Activation)    (None, 5, 5, 384)    0           ['batch_normalization_365[0][0]']
#
#  activation_364 (Activation)    (None, 5, 5, 384)    0           ['batch_normalization_368[0][0]']
#
#  activation_365 (Activation)    (None, 5, 5, 384)    0           ['batch_normalization_369[0][0]']
#
#  batch_normalization_370 (Batch  (None, 5, 5, 192)   576         ['conv2d_367[0][0]']
#  Normalization)
#
#  activation_358 (Activation)    (None, 5, 5, 320)    0           ['batch_normalization_362[0][0]']
#
#  mixed9_0 (Concatenate)         (None, 5, 5, 768)    0           ['activation_360[0][0]',
#                                                                   'activation_361[0][0]']
#
#  concatenate_6 (Concatenate)    (None, 5, 5, 768)    0           ['activation_364[0][0]',
#                                                                   'activation_365[0][0]']
#
#  activation_366 (Activation)    (None, 5, 5, 192)    0           ['batch_normalization_370[0][0]']
#
#  mixed9 (Concatenate)           (None, 5, 5, 2048)   0           ['activation_358[0][0]',
#                                                                   'mixed9_0[0][0]',
#                                                                   'concatenate_6[0][0]',
#                                                                   'activation_366[0][0]']
#
#  conv2d_372 (Conv2D)            (None, 5, 5, 448)    917504      ['mixed9[0][0]']
#
#  batch_normalization_375 (Batch  (None, 5, 5, 448)   1344        ['conv2d_372[0][0]']
#  Normalization)
#
#  activation_371 (Activation)    (None, 5, 5, 448)    0           ['batch_normalization_375[0][0]']
#
#  conv2d_369 (Conv2D)            (None, 5, 5, 384)    786432      ['mixed9[0][0]']
#
#  conv2d_373 (Conv2D)            (None, 5, 5, 384)    1548288     ['activation_371[0][0]']
#
#  batch_normalization_372 (Batch  (None, 5, 5, 384)   1152        ['conv2d_369[0][0]']
#  Normalization)
#
#  batch_normalization_376 (Batch  (None, 5, 5, 384)   1152        ['conv2d_373[0][0]']
#  Normalization)
#
#  activation_368 (Activation)    (None, 5, 5, 384)    0           ['batch_normalization_372[0][0]']
#
#  activation_372 (Activation)    (None, 5, 5, 384)    0           ['batch_normalization_376[0][0]']
#
#  conv2d_370 (Conv2D)            (None, 5, 5, 384)    442368      ['activation_368[0][0]']
#
#  conv2d_371 (Conv2D)            (None, 5, 5, 384)    442368      ['activation_368[0][0]']
#
#  conv2d_374 (Conv2D)            (None, 5, 5, 384)    442368      ['activation_372[0][0]']
#
#  conv2d_375 (Conv2D)            (None, 5, 5, 384)    442368      ['activation_372[0][0]']
#
#  average_pooling2d_35 (AverageP  (None, 5, 5, 2048)  0           ['mixed9[0][0]']
#  ooling2D)
#
#  conv2d_368 (Conv2D)            (None, 5, 5, 320)    655360      ['mixed9[0][0]']
#
#  batch_normalization_373 (Batch  (None, 5, 5, 384)   1152        ['conv2d_370[0][0]']
#  Normalization)
#
#  batch_normalization_374 (Batch  (None, 5, 5, 384)   1152        ['conv2d_371[0][0]']
#  Normalization)
#
#  batch_normalization_377 (Batch  (None, 5, 5, 384)   1152        ['conv2d_374[0][0]']
#  Normalization)
#
#  batch_normalization_378 (Batch  (None, 5, 5, 384)   1152        ['conv2d_375[0][0]']
#  Normalization)
#
#  conv2d_376 (Conv2D)            (None, 5, 5, 192)    393216      ['average_pooling2d_35[0][0]']
#
#  batch_normalization_371 (Batch  (None, 5, 5, 320)   960         ['conv2d_368[0][0]']
#  Normalization)
#
#  activation_369 (Activation)    (None, 5, 5, 384)    0           ['batch_normalization_373[0][0]']
#
#  activation_370 (Activation)    (None, 5, 5, 384)    0           ['batch_normalization_374[0][0]']
#
#  activation_373 (Activation)    (None, 5, 5, 384)    0           ['batch_normalization_377[0][0]']
#
#  activation_374 (Activation)    (None, 5, 5, 384)    0           ['batch_normalization_378[0][0]']
#
#  batch_normalization_379 (Batch  (None, 5, 5, 192)   576         ['conv2d_376[0][0]']
#  Normalization)
#
#  activation_367 (Activation)    (None, 5, 5, 320)    0           ['batch_normalization_371[0][0]']
#
#  mixed9_1 (Concatenate)         (None, 5, 5, 768)    0           ['activation_369[0][0]',
#                                                                   'activation_370[0][0]']
#
#  concatenate_7 (Concatenate)    (None, 5, 5, 768)    0           ['activation_373[0][0]',
#                                                                   'activation_374[0][0]']
#
#  activation_375 (Activation)    (None, 5, 5, 192)    0           ['batch_normalization_379[0][0]']
#
#  mixed10 (Concatenate)          (None, 5, 5, 2048)   0           ['activation_367[0][0]',
#                                                                   'mixed9_1[0][0]',
#                                                                   'concatenate_7[0][0]',
#                                                                   'activation_375[0][0]']
#
# ==================================================================================================
# Total params: 21,802,784
# Trainable params: 0
# Non-trainable params: 21,802,784
# __________________________________________________________________________________________________

# %%
from keras.layers import Convolution2D, Dense, Input, Flatten, Dropout, MaxPooling2D, BatchNormalization, GlobalAveragePooling2D, Concatenate
x = pre_trained_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(1024, activation="relu")(x)

predictions = Dense(13, activation="softmax")(x)

# %%
from keras.layers import Convolution2D, Dense, Input, Flatten, Dropout, MaxPooling2D, BatchNormalization, GlobalAveragePooling2D, Concatenate

# Assume pre_trained_model is already defined
x = pre_trained_model.output

# Add a few convolutional layers
x = Convolution2D(32, (3, 3), activation='relu')(x)
x = MaxPooling2D(pool_size=(2, 2))(x)
x = BatchNormalization()(x)

# Add a few dense layers with dropout and batch normalization
x = Flatten()(x)
x = Dense(512, activation='relu')(x)
x = Dropout(0.5)(x)
x = BatchNormalization()(x)
x = Dense(256, activation='relu')(x)
x = Dropout(0.5)(x)
x = BatchNormalization()(x)

# Add the final dense layer with softmax activation
predictions = Dense(13, activation="softmax")(x)

# %%
model_ = Model(inputs=pre_trained_model.input, outputs=predictions)

# %%
model_.summary()
# Out:
# Model: "model_5"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_4 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv2d_283 (Conv2D)            (None, 111, 111, 32  864         ['input_4[0][0]']
#                                 )
#
#  batch_normalization_286 (Batch  (None, 111, 111, 32  96         ['conv2d_283[0][0]']
#  Normalization)                 )
#
#  activation_282 (Activation)    (None, 111, 111, 32  0           ['batch_normalization_286[0][0]']
#                                 )
#
#  conv2d_284 (Conv2D)            (None, 109, 109, 32  9216        ['activation_282[0][0]']
#                                 )
#
#  batch_normalization_287 (Batch  (None, 109, 109, 32  96         ['conv2d_284[0][0]']
#  Normalization)                 )
#
#  activation_283 (Activation)    (None, 109, 109, 32  0           ['batch_normalization_287[0][0]']
#                                 )
#
#  conv2d_285 (Conv2D)            (None, 109, 109, 64  18432       ['activation_283[0][0]']
#                                 )
#
#  batch_normalization_288 (Batch  (None, 109, 109, 64  192        ['conv2d_285[0][0]']
#  Normalization)                 )
#
#  activation_284 (Activation)    (None, 109, 109, 64  0           ['batch_normalization_288[0][0]']
#                                 )
#
#  max_pooling2d_13 (MaxPooling2D  (None, 54, 54, 64)  0           ['activation_284[0][0]']
#  )
#
#  conv2d_286 (Conv2D)            (None, 54, 54, 80)   5120        ['max_pooling2d_13[0][0]']
#
#  batch_normalization_289 (Batch  (None, 54, 54, 80)  240         ['conv2d_286[0][0]']
#  Normalization)
#
#  activation_285 (Activation)    (None, 54, 54, 80)   0           ['batch_normalization_289[0][0]']
#
#  conv2d_287 (Conv2D)            (None, 52, 52, 192)  138240      ['activation_285[0][0]']
#
#  batch_normalization_290 (Batch  (None, 52, 52, 192)  576        ['conv2d_287[0][0]']
#  Normalization)
#
#  activation_286 (Activation)    (None, 52, 52, 192)  0           ['batch_normalization_290[0][0]']
#
#  max_pooling2d_14 (MaxPooling2D  (None, 25, 25, 192)  0          ['activation_286[0][0]']
#  )
#
#  conv2d_291 (Conv2D)            (None, 25, 25, 64)   12288       ['max_pooling2d_14[0][0]']
#
#  batch_normalization_294 (Batch  (None, 25, 25, 64)  192         ['conv2d_291[0][0]']
#  Normalization)
#
#  activation_290 (Activation)    (None, 25, 25, 64)   0           ['batch_normalization_294[0][0]']
#
#  conv2d_289 (Conv2D)            (None, 25, 25, 48)   9216        ['max_pooling2d_14[0][0]']
#
#  conv2d_292 (Conv2D)            (None, 25, 25, 96)   55296       ['activation_290[0][0]']
#
#  batch_normalization_292 (Batch  (None, 25, 25, 48)  144         ['conv2d_289[0][0]']
#  Normalization)
#
#  batch_normalization_295 (Batch  (None, 25, 25, 96)  288         ['conv2d_292[0][0]']
#  Normalization)
#
#  activation_288 (Activation)    (None, 25, 25, 48)   0           ['batch_normalization_292[0][0]']
#
#  activation_291 (Activation)    (None, 25, 25, 96)   0           ['batch_normalization_295[0][0]']
#
#  average_pooling2d_27 (AverageP  (None, 25, 25, 192)  0          ['max_pooling2d_14[0][0]']
#  ooling2D)
#
#  conv2d_288 (Conv2D)            (None, 25, 25, 64)   12288       ['max_pooling2d_14[0][0]']
#
#  conv2d_290 (Conv2D)            (None, 25, 25, 64)   76800       ['activation_288[0][0]']
#
#  conv2d_293 (Conv2D)            (None, 25, 25, 96)   82944       ['activation_291[0][0]']
#
#  conv2d_294 (Conv2D)            (None, 25, 25, 32)   6144        ['average_pooling2d_27[0][0]']
#
#  batch_normalization_291 (Batch  (None, 25, 25, 64)  192         ['conv2d_288[0][0]']
#  Normalization)
#
#  batch_normalization_293 (Batch  (None, 25, 25, 64)  192         ['conv2d_290[0][0]']
#  Normalization)
#
#  batch_normalization_296 (Batch  (None, 25, 25, 96)  288         ['conv2d_293[0][0]']
#  Normalization)
#
#  batch_normalization_297 (Batch  (None, 25, 25, 32)  96          ['conv2d_294[0][0]']
#  Normalization)
#
#  activation_287 (Activation)    (None, 25, 25, 64)   0           ['batch_normalization_291[0][0]']
#
#  activation_289 (Activation)    (None, 25, 25, 64)   0           ['batch_normalization_293[0][0]']
#
#  activation_292 (Activation)    (None, 25, 25, 96)   0           ['batch_normalization_296[0][0]']
#
#  activation_293 (Activation)    (None, 25, 25, 32)   0           ['batch_normalization_297[0][0]']
#
#  mixed0 (Concatenate)           (None, 25, 25, 256)  0           ['activation_287[0][0]',
#                                                                   'activation_289[0][0]',
#                                                                   'activation_292[0][0]',
#                                                                   'activation_293[0][0]']
#
#  conv2d_298 (Conv2D)            (None, 25, 25, 64)   16384       ['mixed0[0][0]']
#
#  batch_normalization_301 (Batch  (None, 25, 25, 64)  192         ['conv2d_298[0][0]']
#  Normalization)
#
#  activation_297 (Activation)    (None, 25, 25, 64)   0           ['batch_normalization_301[0][0]']
#
#  conv2d_296 (Conv2D)            (None, 25, 25, 48)   12288       ['mixed0[0][0]']
#
#  conv2d_299 (Conv2D)            (None, 25, 25, 96)   55296       ['activation_297[0][0]']
#
#  batch_normalization_299 (Batch  (None, 25, 25, 48)  144         ['conv2d_296[0][0]']
#  Normalization)
#
#  batch_normalization_302 (Batch  (None, 25, 25, 96)  288         ['conv2d_299[0][0]']
#  Normalization)
#
#  activation_295 (Activation)    (None, 25, 25, 48)   0           ['batch_normalization_299[0][0]']
#
#  activation_298 (Activation)    (None, 25, 25, 96)   0           ['batch_normalization_302[0][0]']
#
#  average_pooling2d_28 (AverageP  (None, 25, 25, 256)  0          ['mixed0[0][0]']
#  ooling2D)
#
#  conv2d_295 (Conv2D)            (None, 25, 25, 64)   16384       ['mixed0[0][0]']
#
#  conv2d_297 (Conv2D)            (None, 25, 25, 64)   76800       ['activation_295[0][0]']
#
#  conv2d_300 (Conv2D)            (None, 25, 25, 96)   82944       ['activation_298[0][0]']
#
#  conv2d_301 (Conv2D)            (None, 25, 25, 64)   16384       ['average_pooling2d_28[0][0]']
#
#  batch_normalization_298 (Batch  (None, 25, 25, 64)  192         ['conv2d_295[0][0]']
#  Normalization)
#
#  batch_normalization_300 (Batch  (None, 25, 25, 64)  192         ['conv2d_297[0][0]']
#  Normalization)
#
#  batch_normalization_303 (Batch  (None, 25, 25, 96)  288         ['conv2d_300[0][0]']
#  Normalization)
#
#  batch_normalization_304 (Batch  (None, 25, 25, 64)  192         ['conv2d_301[0][0]']
#  Normalization)
#
#  activation_294 (Activation)    (None, 25, 25, 64)   0           ['batch_normalization_298[0][0]']
#
#  activation_296 (Activation)    (None, 25, 25, 64)   0           ['batch_normalization_300[0][0]']
#
#  activation_299 (Activation)    (None, 25, 25, 96)   0           ['batch_normalization_303[0][0]']
#
#  activation_300 (Activation)    (None, 25, 25, 64)   0           ['batch_normalization_304[0][0]']
#
#  mixed1 (Concatenate)           (None, 25, 25, 288)  0           ['activation_294[0][0]',
#                                                                   'activation_296[0][0]',
#                                                                   'activation_299[0][0]',
#                                                                   'activation_300[0][0]']
#
#  conv2d_305 (Conv2D)            (None, 25, 25, 64)   18432       ['mixed1[0][0]']
#
#  batch_normalization_308 (Batch  (None, 25, 25, 64)  192         ['conv2d_305[0][0]']
#  Normalization)
#
#  activation_304 (Activation)    (None, 25, 25, 64)   0           ['batch_normalization_308[0][0]']
#
#  conv2d_303 (Conv2D)            (None, 25, 25, 48)   13824       ['mixed1[0][0]']
#
#  conv2d_306 (Conv2D)            (None, 25, 25, 96)   55296       ['activation_304[0][0]']
#
#  batch_normalization_306 (Batch  (None, 25, 25, 48)  144         ['conv2d_303[0][0]']
#  Normalization)
#
#  batch_normalization_309 (Batch  (None, 25, 25, 96)  288         ['conv2d_306[0][0]']
#  Normalization)
#
#  activation_302 (Activation)    (None, 25, 25, 48)   0           ['batch_normalization_306[0][0]']
#
#  activation_305 (Activation)    (None, 25, 25, 96)   0           ['batch_normalization_309[0][0]']
#
#  average_pooling2d_29 (AverageP  (None, 25, 25, 288)  0          ['mixed1[0][0]']
#  ooling2D)
#
#  conv2d_302 (Conv2D)            (None, 25, 25, 64)   18432       ['mixed1[0][0]']
#
#  conv2d_304 (Conv2D)            (None, 25, 25, 64)   76800       ['activation_302[0][0]']
#
#  conv2d_307 (Conv2D)            (None, 25, 25, 96)   82944       ['activation_305[0][0]']
#
#  conv2d_308 (Conv2D)            (None, 25, 25, 64)   18432       ['average_pooling2d_29[0][0]']
#
#  batch_normalization_305 (Batch  (None, 25, 25, 64)  192         ['conv2d_302[0][0]']
#  Normalization)
#
#  batch_normalization_307 (Batch  (None, 25, 25, 64)  192         ['conv2d_304[0][0]']
#  Normalization)
#
#  batch_normalization_310 (Batch  (None, 25, 25, 96)  288         ['conv2d_307[0][0]']
#  Normalization)
#
#  batch_normalization_311 (Batch  (None, 25, 25, 64)  192         ['conv2d_308[0][0]']
#  Normalization)
#
#  activation_301 (Activation)    (None, 25, 25, 64)   0           ['batch_normalization_305[0][0]']
#
#  activation_303 (Activation)    (None, 25, 25, 64)   0           ['batch_normalization_307[0][0]']
#
#  activation_306 (Activation)    (None, 25, 25, 96)   0           ['batch_normalization_310[0][0]']
#
#  activation_307 (Activation)    (None, 25, 25, 64)   0           ['batch_normalization_311[0][0]']
#
#  mixed2 (Concatenate)           (None, 25, 25, 288)  0           ['activation_301[0][0]',
#                                                                   'activation_303[0][0]',
#                                                                   'activation_306[0][0]',
#                                                                   'activation_307[0][0]']
#
#  conv2d_310 (Conv2D)            (None, 25, 25, 64)   18432       ['mixed2[0][0]']
#
#  batch_normalization_313 (Batch  (None, 25, 25, 64)  192         ['conv2d_310[0][0]']
#  Normalization)
#
#  activation_309 (Activation)    (None, 25, 25, 64)   0           ['batch_normalization_313[0][0]']
#
#  conv2d_311 (Conv2D)            (None, 25, 25, 96)   55296       ['activation_309[0][0]']
#
#  batch_normalization_314 (Batch  (None, 25, 25, 96)  288         ['conv2d_311[0][0]']
#  Normalization)
#
#  activation_310 (Activation)    (None, 25, 25, 96)   0           ['batch_normalization_314[0][0]']
#
#  conv2d_309 (Conv2D)            (None, 12, 12, 384)  995328      ['mixed2[0][0]']
#
#  conv2d_312 (Conv2D)            (None, 12, 12, 96)   82944       ['activation_310[0][0]']
#
#  batch_normalization_312 (Batch  (None, 12, 12, 384)  1152       ['conv2d_309[0][0]']
#  Normalization)
#
#  batch_normalization_315 (Batch  (None, 12, 12, 96)  288         ['conv2d_312[0][0]']
#  Normalization)
#
#  activation_308 (Activation)    (None, 12, 12, 384)  0           ['batch_normalization_312[0][0]']
#
#  activation_311 (Activation)    (None, 12, 12, 96)   0           ['batch_normalization_315[0][0]']
#
#  max_pooling2d_15 (MaxPooling2D  (None, 12, 12, 288)  0          ['mixed2[0][0]']
#  )
#
#  mixed3 (Concatenate)           (None, 12, 12, 768)  0           ['activation_308[0][0]',
#                                                                   'activation_311[0][0]',
#                                                                   'max_pooling2d_15[0][0]']
#
#  conv2d_317 (Conv2D)            (None, 12, 12, 128)  98304       ['mixed3[0][0]']
#
#  batch_normalization_320 (Batch  (None, 12, 12, 128)  384        ['conv2d_317[0][0]']
#  Normalization)
#
#  activation_316 (Activation)    (None, 12, 12, 128)  0           ['batch_normalization_320[0][0]']
#
#  conv2d_318 (Conv2D)            (None, 12, 12, 128)  114688      ['activation_316[0][0]']
#
#  batch_normalization_321 (Batch  (None, 12, 12, 128)  384        ['conv2d_318[0][0]']
#  Normalization)
#
#  activation_317 (Activation)    (None, 12, 12, 128)  0           ['batch_normalization_321[0][0]']
#
#  conv2d_314 (Conv2D)            (None, 12, 12, 128)  98304       ['mixed3[0][0]']
#
#  conv2d_319 (Conv2D)            (None, 12, 12, 128)  114688      ['activation_317[0][0]']
#
#  batch_normalization_317 (Batch  (None, 12, 12, 128)  384        ['conv2d_314[0][0]']
#  Normalization)
#
#  batch_normalization_322 (Batch  (None, 12, 12, 128)  384        ['conv2d_319[0][0]']
#  Normalization)
#
#  activation_313 (Activation)    (None, 12, 12, 128)  0           ['batch_normalization_317[0][0]']
#
#  activation_318 (Activation)    (None, 12, 12, 128)  0           ['batch_normalization_322[0][0]']
#
#  conv2d_315 (Conv2D)            (None, 12, 12, 128)  114688      ['activation_313[0][0]']
#
#  conv2d_320 (Conv2D)            (None, 12, 12, 128)  114688      ['activation_318[0][0]']
#
#  batch_normalization_318 (Batch  (None, 12, 12, 128)  384        ['conv2d_315[0][0]']
#  Normalization)
#
#  batch_normalization_323 (Batch  (None, 12, 12, 128)  384        ['conv2d_320[0][0]']
#  Normalization)
#
#  activation_314 (Activation)    (None, 12, 12, 128)  0           ['batch_normalization_318[0][0]']
#
#  activation_319 (Activation)    (None, 12, 12, 128)  0           ['batch_normalization_323[0][0]']
#
#  average_pooling2d_30 (AverageP  (None, 12, 12, 768)  0          ['mixed3[0][0]']
#  ooling2D)
#
#  conv2d_313 (Conv2D)            (None, 12, 12, 192)  147456      ['mixed3[0][0]']
#
#  conv2d_316 (Conv2D)            (None, 12, 12, 192)  172032      ['activation_314[0][0]']
#
#  conv2d_321 (Conv2D)            (None, 12, 12, 192)  172032      ['activation_319[0][0]']
#
#  conv2d_322 (Conv2D)            (None, 12, 12, 192)  147456      ['average_pooling2d_30[0][0]']
#
#  batch_normalization_316 (Batch  (None, 12, 12, 192)  576        ['conv2d_313[0][0]']
#  Normalization)
#
#  batch_normalization_319 (Batch  (None, 12, 12, 192)  576        ['conv2d_316[0][0]']
#  Normalization)
#
#  batch_normalization_324 (Batch  (None, 12, 12, 192)  576        ['conv2d_321[0][0]']
#  Normalization)
#
#  batch_normalization_325 (Batch  (None, 12, 12, 192)  576        ['conv2d_322[0][0]']
#  Normalization)
#
#  activation_312 (Activation)    (None, 12, 12, 192)  0           ['batch_normalization_316[0][0]']
#
#  activation_315 (Activation)    (None, 12, 12, 192)  0           ['batch_normalization_319[0][0]']
#
#  activation_320 (Activation)    (None, 12, 12, 192)  0           ['batch_normalization_324[0][0]']
#
#  activation_321 (Activation)    (None, 12, 12, 192)  0           ['batch_normalization_325[0][0]']
#
#  mixed4 (Concatenate)           (None, 12, 12, 768)  0           ['activation_312[0][0]',
#                                                                   'activation_315[0][0]',
#                                                                   'activation_320[0][0]',
#                                                                   'activation_321[0][0]']
#
#  conv2d_327 (Conv2D)            (None, 12, 12, 160)  122880      ['mixed4[0][0]']
#
#  batch_normalization_330 (Batch  (None, 12, 12, 160)  480        ['conv2d_327[0][0]']
#  Normalization)
#
#  activation_326 (Activation)    (None, 12, 12, 160)  0           ['batch_normalization_330[0][0]']
#
#  conv2d_328 (Conv2D)            (None, 12, 12, 160)  179200      ['activation_326[0][0]']
#
#  batch_normalization_331 (Batch  (None, 12, 12, 160)  480        ['conv2d_328[0][0]']
#  Normalization)
#
#  activation_327 (Activation)    (None, 12, 12, 160)  0           ['batch_normalization_331[0][0]']
#
#  conv2d_324 (Conv2D)            (None, 12, 12, 160)  122880      ['mixed4[0][0]']
#
#  conv2d_329 (Conv2D)            (None, 12, 12, 160)  179200      ['activation_327[0][0]']
#
#  batch_normalization_327 (Batch  (None, 12, 12, 160)  480        ['conv2d_324[0][0]']
#  Normalization)
#
#  batch_normalization_332 (Batch  (None, 12, 12, 160)  480        ['conv2d_329[0][0]']
#  Normalization)
#
#  activation_323 (Activation)    (None, 12, 12, 160)  0           ['batch_normalization_327[0][0]']
#
#  activation_328 (Activation)    (None, 12, 12, 160)  0           ['batch_normalization_332[0][0]']
#
#  conv2d_325 (Conv2D)            (None, 12, 12, 160)  179200      ['activation_323[0][0]']
#
#  conv2d_330 (Conv2D)            (None, 12, 12, 160)  179200      ['activation_328[0][0]']
#
#  batch_normalization_328 (Batch  (None, 12, 12, 160)  480        ['conv2d_325[0][0]']
#  Normalization)
#
#  batch_normalization_333 (Batch  (None, 12, 12, 160)  480        ['conv2d_330[0][0]']
#  Normalization)
#
#  activation_324 (Activation)    (None, 12, 12, 160)  0           ['batch_normalization_328[0][0]']
#
#  activation_329 (Activation)    (None, 12, 12, 160)  0           ['batch_normalization_333[0][0]']
#
#  average_pooling2d_31 (AverageP  (None, 12, 12, 768)  0          ['mixed4[0][0]']
#  ooling2D)
#
#  conv2d_323 (Conv2D)            (None, 12, 12, 192)  147456      ['mixed4[0][0]']
#
#  conv2d_326 (Conv2D)            (None, 12, 12, 192)  215040      ['activation_324[0][0]']
#
#  conv2d_331 (Conv2D)            (None, 12, 12, 192)  215040      ['activation_329[0][0]']
#
#  conv2d_332 (Conv2D)            (None, 12, 12, 192)  147456      ['average_pooling2d_31[0][0]']
#
#  batch_normalization_326 (Batch  (None, 12, 12, 192)  576        ['conv2d_323[0][0]']
#  Normalization)
#
#  batch_normalization_329 (Batch  (None, 12, 12, 192)  576        ['conv2d_326[0][0]']
#  Normalization)
#
#  batch_normalization_334 (Batch  (None, 12, 12, 192)  576        ['conv2d_331[0][0]']
#  Normalization)
#
#  batch_normalization_335 (Batch  (None, 12, 12, 192)  576        ['conv2d_332[0][0]']
#  Normalization)
#
#  activation_322 (Activation)    (None, 12, 12, 192)  0           ['batch_normalization_326[0][0]']
#
#  activation_325 (Activation)    (None, 12, 12, 192)  0           ['batch_normalization_329[0][0]']
#
#  activation_330 (Activation)    (None, 12, 12, 192)  0           ['batch_normalization_334[0][0]']
#
#  activation_331 (Activation)    (None, 12, 12, 192)  0           ['batch_normalization_335[0][0]']
#
#  mixed5 (Concatenate)           (None, 12, 12, 768)  0           ['activation_322[0][0]',
#                                                                   'activation_325[0][0]',
#                                                                   'activation_330[0][0]',
#                                                                   'activation_331[0][0]']
#
#  conv2d_337 (Conv2D)            (None, 12, 12, 160)  122880      ['mixed5[0][0]']
#
#  batch_normalization_340 (Batch  (None, 12, 12, 160)  480        ['conv2d_337[0][0]']
#  Normalization)
#
#  activation_336 (Activation)    (None, 12, 12, 160)  0           ['batch_normalization_340[0][0]']
#
#  conv2d_338 (Conv2D)            (None, 12, 12, 160)  179200      ['activation_336[0][0]']
#
#  batch_normalization_341 (Batch  (None, 12, 12, 160)  480        ['conv2d_338[0][0]']
#  Normalization)
#
#  activation_337 (Activation)    (None, 12, 12, 160)  0           ['batch_normalization_341[0][0]']
#
#  conv2d_334 (Conv2D)            (None, 12, 12, 160)  122880      ['mixed5[0][0]']
#
#  conv2d_339 (Conv2D)            (None, 12, 12, 160)  179200      ['activation_337[0][0]']
#
#  batch_normalization_337 (Batch  (None, 12, 12, 160)  480        ['conv2d_334[0][0]']
#  Normalization)
#
#  batch_normalization_342 (Batch  (None, 12, 12, 160)  480        ['conv2d_339[0][0]']
#  Normalization)
#
#  activation_333 (Activation)    (None, 12, 12, 160)  0           ['batch_normalization_337[0][0]']
#
#  activation_338 (Activation)    (None, 12, 12, 160)  0           ['batch_normalization_342[0][0]']
#
#  conv2d_335 (Conv2D)            (None, 12, 12, 160)  179200      ['activation_333[0][0]']
#
#  conv2d_340 (Conv2D)            (None, 12, 12, 160)  179200      ['activation_338[0][0]']
#
#  batch_normalization_338 (Batch  (None, 12, 12, 160)  480        ['conv2d_335[0][0]']
#  Normalization)
#
#  batch_normalization_343 (Batch  (None, 12, 12, 160)  480        ['conv2d_340[0][0]']
#  Normalization)
#
#  activation_334 (Activation)    (None, 12, 12, 160)  0           ['batch_normalization_338[0][0]']
#
#  activation_339 (Activation)    (None, 12, 12, 160)  0           ['batch_normalization_343[0][0]']
#
#  average_pooling2d_32 (AverageP  (None, 12, 12, 768)  0          ['mixed5[0][0]']
#  ooling2D)
#
#  conv2d_333 (Conv2D)            (None, 12, 12, 192)  147456      ['mixed5[0][0]']
#
#  conv2d_336 (Conv2D)            (None, 12, 12, 192)  215040      ['activation_334[0][0]']
#
#  conv2d_341 (Conv2D)            (None, 12, 12, 192)  215040      ['activation_339[0][0]']
#
#  conv2d_342 (Conv2D)            (None, 12, 12, 192)  147456      ['average_pooling2d_32[0][0]']
#
#  batch_normalization_336 (Batch  (None, 12, 12, 192)  576        ['conv2d_333[0][0]']
#  Normalization)
#
#  batch_normalization_339 (Batch  (None, 12, 12, 192)  576        ['conv2d_336[0][0]']
#  Normalization)
#
#  batch_normalization_344 (Batch  (None, 12, 12, 192)  576        ['conv2d_341[0][0]']
#  Normalization)
#
#  batch_normalization_345 (Batch  (None, 12, 12, 192)  576        ['conv2d_342[0][0]']
#  Normalization)
#
#  activation_332 (Activation)    (None, 12, 12, 192)  0           ['batch_normalization_336[0][0]']
#
#  activation_335 (Activation)    (None, 12, 12, 192)  0           ['batch_normalization_339[0][0]']
#
# ...
#
#  activation_362 (Activation)    (None, 5, 5, 448)    0           ['batch_normalization_366[0][0]']
#
#  conv2d_360 (Conv2D)            (None, 5, 5, 384)    491520      ['mixed8[0][0]']
#
#  conv2d_364 (Conv2D)            (None, 5, 5, 384)    1548288     ['activation_362[0][0]']
#
#  batch_normalization_363 (Batch  (None, 5, 5, 384)   1152        ['conv2d_360[0][0]']
#  Normalization)
#
#  batch_normalization_367 (Batch  (None, 5, 5, 384)   1152        ['conv2d_364[0][0]']
#  Normalization)
#
#  activation_359 (Activation)    (None, 5, 5, 384)    0           ['batch_normalization_363[0][0]']
#
#  activation_363 (Activation)    (None, 5, 5, 384)    0           ['batch_normalization_367[0][0]']
#
#  conv2d_361 (Conv2D)            (None, 5, 5, 384)    442368      ['activation_359[0][0]']
#
#  conv2d_362 (Conv2D)            (None, 5, 5, 384)    442368      ['activation_359[0][0]']
#
#  conv2d_365 (Conv2D)            (None, 5, 5, 384)    442368      ['activation_363[0][0]']
#
#  conv2d_366 (Conv2D)            (None, 5, 5, 384)    442368      ['activation_363[0][0]']
#
#  average_pooling2d_34 (AverageP  (None, 5, 5, 1280)  0           ['mixed8[0][0]']
#  ooling2D)
#
#  conv2d_359 (Conv2D)            (None, 5, 5, 320)    409600      ['mixed8[0][0]']
#
#  batch_normalization_364 (Batch  (None, 5, 5, 384)   1152        ['conv2d_361[0][0]']
#  Normalization)
#
#  batch_normalization_365 (Batch  (None, 5, 5, 384)   1152        ['conv2d_362[0][0]']
#  Normalization)
#
#  batch_normalization_368 (Batch  (None, 5, 5, 384)   1152        ['conv2d_365[0][0]']
#  Normalization)
#
#  batch_normalization_369 (Batch  (None, 5, 5, 384)   1152        ['conv2d_366[0][0]']
#  Normalization)
#
#  conv2d_367 (Conv2D)            (None, 5, 5, 192)    245760      ['average_pooling2d_34[0][0]']
#
#  batch_normalization_362 (Batch  (None, 5, 5, 320)   960         ['conv2d_359[0][0]']
#  Normalization)
#
#  activation_360 (Activation)    (None, 5, 5, 384)    0           ['batch_normalization_364[0][0]']
#
#  activation_361 (Activation)    (None, 5, 5, 384)    0           ['batch_normalization_365[0][0]']
#
#  activation_364 (Activation)    (None, 5, 5, 384)    0           ['batch_normalization_368[0][0]']
#
#  activation_365 (Activation)    (None, 5, 5, 384)    0           ['batch_normalization_369[0][0]']
#
#  batch_normalization_370 (Batch  (None, 5, 5, 192)   576         ['conv2d_367[0][0]']
#  Normalization)
#
#  activation_358 (Activation)    (None, 5, 5, 320)    0           ['batch_normalization_362[0][0]']
#
#  mixed9_0 (Concatenate)         (None, 5, 5, 768)    0           ['activation_360[0][0]',
#                                                                   'activation_361[0][0]']
#
#  concatenate_6 (Concatenate)    (None, 5, 5, 768)    0           ['activation_364[0][0]',
#                                                                   'activation_365[0][0]']
#
#  activation_366 (Activation)    (None, 5, 5, 192)    0           ['batch_normalization_370[0][0]']
#
#  mixed9 (Concatenate)           (None, 5, 5, 2048)   0           ['activation_358[0][0]',
#                                                                   'mixed9_0[0][0]',
#                                                                   'concatenate_6[0][0]',
#                                                                   'activation_366[0][0]']
#
#  conv2d_372 (Conv2D)            (None, 5, 5, 448)    917504      ['mixed9[0][0]']
#
#  batch_normalization_375 (Batch  (None, 5, 5, 448)   1344        ['conv2d_372[0][0]']
#  Normalization)
#
#  activation_371 (Activation)    (None, 5, 5, 448)    0           ['batch_normalization_375[0][0]']
#
#  conv2d_369 (Conv2D)            (None, 5, 5, 384)    786432      ['mixed9[0][0]']
#
#  conv2d_373 (Conv2D)            (None, 5, 5, 384)    1548288     ['activation_371[0][0]']
#
#  batch_normalization_372 (Batch  (None, 5, 5, 384)   1152        ['conv2d_369[0][0]']
#  Normalization)
#
#  batch_normalization_376 (Batch  (None, 5, 5, 384)   1152        ['conv2d_373[0][0]']
#  Normalization)
#
#  activation_368 (Activation)    (None, 5, 5, 384)    0           ['batch_normalization_372[0][0]']
#
#  activation_372 (Activation)    (None, 5, 5, 384)    0           ['batch_normalization_376[0][0]']
#
#  conv2d_370 (Conv2D)            (None, 5, 5, 384)    442368      ['activation_368[0][0]']
#
#  conv2d_371 (Conv2D)            (None, 5, 5, 384)    442368      ['activation_368[0][0]']
#
#  conv2d_374 (Conv2D)            (None, 5, 5, 384)    442368      ['activation_372[0][0]']
#
#  conv2d_375 (Conv2D)            (None, 5, 5, 384)    442368      ['activation_372[0][0]']
#
#  average_pooling2d_35 (AverageP  (None, 5, 5, 2048)  0           ['mixed9[0][0]']
#  ooling2D)
#
#  conv2d_368 (Conv2D)            (None, 5, 5, 320)    655360      ['mixed9[0][0]']
#
#  batch_normalization_373 (Batch  (None, 5, 5, 384)   1152        ['conv2d_370[0][0]']
#  Normalization)
#
#  batch_normalization_374 (Batch  (None, 5, 5, 384)   1152        ['conv2d_371[0][0]']
#  Normalization)
#
#  batch_normalization_377 (Batch  (None, 5, 5, 384)   1152        ['conv2d_374[0][0]']
#  Normalization)
#
#  batch_normalization_378 (Batch  (None, 5, 5, 384)   1152        ['conv2d_375[0][0]']
#  Normalization)
#
#  conv2d_376 (Conv2D)            (None, 5, 5, 192)    393216      ['average_pooling2d_35[0][0]']
#
#  batch_normalization_371 (Batch  (None, 5, 5, 320)   960         ['conv2d_368[0][0]']
#  Normalization)
#
#  activation_369 (Activation)    (None, 5, 5, 384)    0           ['batch_normalization_373[0][0]']
#
#  activation_370 (Activation)    (None, 5, 5, 384)    0           ['batch_normalization_374[0][0]']
#
#  activation_373 (Activation)    (None, 5, 5, 384)    0           ['batch_normalization_377[0][0]']
#
#  activation_374 (Activation)    (None, 5, 5, 384)    0           ['batch_normalization_378[0][0]']
#
#  batch_normalization_379 (Batch  (None, 5, 5, 192)   576         ['conv2d_376[0][0]']
#  Normalization)
#
#  activation_367 (Activation)    (None, 5, 5, 320)    0           ['batch_normalization_371[0][0]']
#
#  mixed9_1 (Concatenate)         (None, 5, 5, 768)    0           ['activation_369[0][0]',
#                                                                   'activation_370[0][0]']
#
#  concatenate_7 (Concatenate)    (None, 5, 5, 768)    0           ['activation_373[0][0]',
#                                                                   'activation_374[0][0]']
#
#  activation_375 (Activation)    (None, 5, 5, 192)    0           ['batch_normalization_379[0][0]']
#
#  mixed10 (Concatenate)          (None, 5, 5, 2048)   0           ['activation_367[0][0]',
#                                                                   'mixed9_1[0][0]',
#                                                                   'concatenate_7[0][0]',
#                                                                   'activation_375[0][0]']
#
#  global_average_pooling2d_5 (Gl  (None, 2048)        0           ['mixed10[0][0]']
#  obalAveragePooling2D)
#
#  dense_13 (Dense)               (None, 1024)         2098176     ['global_average_pooling2d_5[0][0
#                                                                  ]']
#
#  dense_14 (Dense)               (None, 13)           13325       ['dense_13[0][0]']
#
# ==================================================================================================
# Total params: 23,914,285
# Trainable params: 2,111,501
# Non-trainable params: 21,802,784
# __________________________________________________________________________________________________

# %%
# Stops the main frozen body of the architecture to be updated through backprop
for layer in model_.layers[:52]:
    layer.trainable = False

# %%
model_.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv2d_188 (Conv2D)            (None, 111, 111, 32  864         ['input_3[0][0]']
#                                 )
#
#  batch_normalization_188 (Batch  (None, 111, 111, 32  96         ['conv2d_188[0][0]']
#  Normalization)                 )
#
#  activation_188 (Activation)    (None, 111, 111, 32  0           ['batch_normalization_188[0][0]']
#                                 )
#
#  conv2d_189 (Conv2D)            (None, 109, 109, 32  9216        ['activation_188[0][0]']
#                                 )
#
#  batch_normalization_189 (Batch  (None, 109, 109, 32  96         ['conv2d_189[0][0]']
#  Normalization)                 )
#
#  activation_189 (Activation)    (None, 109, 109, 32  0           ['batch_normalization_189[0][0]']
#                                 )
#
#  conv2d_190 (Conv2D)            (None, 109, 109, 64  18432       ['activation_189[0][0]']
#                                 )
#
#  batch_normalization_190 (Batch  (None, 109, 109, 64  192        ['conv2d_190[0][0]']
#  Normalization)                 )
#
#  activation_190 (Activation)    (None, 109, 109, 64  0           ['batch_normalization_190[0][0]']
#                                 )
#
#  max_pooling2d_8 (MaxPooling2D)  (None, 54, 54, 64)  0           ['activation_190[0][0]']
#
#  conv2d_191 (Conv2D)            (None, 54, 54, 80)   5120        ['max_pooling2d_8[0][0]']
#
#  batch_normalization_191 (Batch  (None, 54, 54, 80)  240         ['conv2d_191[0][0]']
#  Normalization)
#
#  activation_191 (Activation)    (None, 54, 54, 80)   0           ['batch_normalization_191[0][0]']
#
#  conv2d_192 (Conv2D)            (None, 52, 52, 192)  138240      ['activation_191[0][0]']
#
#  batch_normalization_192 (Batch  (None, 52, 52, 192)  576        ['conv2d_192[0][0]']
#  Normalization)
#
#  activation_192 (Activation)    (None, 52, 52, 192)  0           ['batch_normalization_192[0][0]']
#
#  max_pooling2d_9 (MaxPooling2D)  (None, 25, 25, 192)  0          ['activation_192[0][0]']
#
#  conv2d_196 (Conv2D)            (None, 25, 25, 64)   12288       ['max_pooling2d_9[0][0]']
#
#  batch_normalization_196 (Batch  (None, 25, 25, 64)  192         ['conv2d_196[0][0]']
#  Normalization)
#
#  activation_196 (Activation)    (None, 25, 25, 64)   0           ['batch_normalization_196[0][0]']
#
#  conv2d_194 (Conv2D)            (None, 25, 25, 48)   9216        ['max_pooling2d_9[0][0]']
#
#  conv2d_197 (Conv2D)            (None, 25, 25, 96)   55296       ['activation_196[0][0]']
#
#  batch_normalization_194 (Batch  (None, 25, 25, 48)  144         ['conv2d_194[0][0]']
#  Normalization)
#
#  batch_normalization_197 (Batch  (None, 25, 25, 96)  288         ['conv2d_197[0][0]']
#  Normalization)
#
#  activation_194 (Activation)    (None, 25, 25, 48)   0           ['batch_normalization_194[0][0]']
#
#  activation_197 (Activation)    (None, 25, 25, 96)   0           ['batch_normalization_197[0][0]']
#
#  average_pooling2d_18 (AverageP  (None, 25, 25, 192)  0          ['max_pooling2d_9[0][0]']
#  ooling2D)
#
#  conv2d_193 (Conv2D)            (None, 25, 25, 64)   12288       ['max_pooling2d_9[0][0]']
#
#  conv2d_195 (Conv2D)            (None, 25, 25, 64)   76800       ['activation_194[0][0]']
#
#  conv2d_198 (Conv2D)            (None, 25, 25, 96)   82944       ['activation_197[0][0]']
#
#  conv2d_199 (Conv2D)            (None, 25, 25, 32)   6144        ['average_pooling2d_18[0][0]']
#
#  batch_normalization_193 (Batch  (None, 25, 25, 64)  192         ['conv2d_193[0][0]']
#  Normalization)
#
#  batch_normalization_195 (Batch  (None, 25, 25, 64)  192         ['conv2d_195[0][0]']
#  Normalization)
#
#  batch_normalization_198 (Batch  (None, 25, 25, 96)  288         ['conv2d_198[0][0]']
#  Normalization)
#
#  batch_normalization_199 (Batch  (None, 25, 25, 32)  96          ['conv2d_199[0][0]']
#  Normalization)
#
#  activation_193 (Activation)    (None, 25, 25, 64)   0           ['batch_normalization_193[0][0]']
#
#  activation_195 (Activation)    (None, 25, 25, 64)   0           ['batch_normalization_195[0][0]']
#
#  activation_198 (Activation)    (None, 25, 25, 96)   0           ['batch_normalization_198[0][0]']
#
#  activation_199 (Activation)    (None, 25, 25, 32)   0           ['batch_normalization_199[0][0]']
#
#  mixed0 (Concatenate)           (None, 25, 25, 256)  0           ['activation_193[0][0]',
#                                                                   'activation_195[0][0]',
#                                                                   'activation_198[0][0]',
#                                                                   'activation_199[0][0]']
#
#  conv2d_203 (Conv2D)            (None, 25, 25, 64)   16384       ['mixed0[0][0]']
#
#  batch_normalization_203 (Batch  (None, 25, 25, 64)  192         ['conv2d_203[0][0]']
#  Normalization)
#
#  activation_203 (Activation)    (None, 25, 25, 64)   0           ['batch_normalization_203[0][0]']
#
#  conv2d_201 (Conv2D)            (None, 25, 25, 48)   12288       ['mixed0[0][0]']
#
#  conv2d_204 (Conv2D)            (None, 25, 25, 96)   55296       ['activation_203[0][0]']
#
#  batch_normalization_201 (Batch  (None, 25, 25, 48)  144         ['conv2d_201[0][0]']
#  Normalization)
#
#  batch_normalization_204 (Batch  (None, 25, 25, 96)  288         ['conv2d_204[0][0]']
#  Normalization)
#
#  activation_201 (Activation)    (None, 25, 25, 48)   0           ['batch_normalization_201[0][0]']
#
#  activation_204 (Activation)    (None, 25, 25, 96)   0           ['batch_normalization_204[0][0]']
#
#  average_pooling2d_19 (AverageP  (None, 25, 25, 256)  0          ['mixed0[0][0]']
#  ooling2D)
#
#  conv2d_200 (Conv2D)            (None, 25, 25, 64)   16384       ['mixed0[0][0]']
#
#  conv2d_202 (Conv2D)            (None, 25, 25, 64)   76800       ['activation_201[0][0]']
#
#  conv2d_205 (Conv2D)            (None, 25, 25, 96)   82944       ['activation_204[0][0]']
#
#  conv2d_206 (Conv2D)            (None, 25, 25, 64)   16384       ['average_pooling2d_19[0][0]']
#
#  batch_normalization_200 (Batch  (None, 25, 25, 64)  192         ['conv2d_200[0][0]']
#  Normalization)
#
#  batch_normalization_202 (Batch  (None, 25, 25, 64)  192         ['conv2d_202[0][0]']
#  Normalization)
#
#  batch_normalization_205 (Batch  (None, 25, 25, 96)  288         ['conv2d_205[0][0]']
#  Normalization)
#
#  batch_normalization_206 (Batch  (None, 25, 25, 64)  192         ['conv2d_206[0][0]']
#  Normalization)
#
#  activation_200 (Activation)    (None, 25, 25, 64)   0           ['batch_normalization_200[0][0]']
#
#  activation_202 (Activation)    (None, 25, 25, 64)   0           ['batch_normalization_202[0][0]']
#
#  activation_205 (Activation)    (None, 25, 25, 96)   0           ['batch_normalization_205[0][0]']
#
#  activation_206 (Activation)    (None, 25, 25, 64)   0           ['batch_normalization_206[0][0]']
#
#  mixed1 (Concatenate)           (None, 25, 25, 288)  0           ['activation_200[0][0]',
#                                                                   'activation_202[0][0]',
#                                                                   'activation_205[0][0]',
#                                                                   'activation_206[0][0]']
#
#  conv2d_210 (Conv2D)            (None, 25, 25, 64)   18432       ['mixed1[0][0]']
#
#  batch_normalization_210 (Batch  (None, 25, 25, 64)  192         ['conv2d_210[0][0]']
#  Normalization)
#
#  activation_210 (Activation)    (None, 25, 25, 64)   0           ['batch_normalization_210[0][0]']
#
#  conv2d_208 (Conv2D)            (None, 25, 25, 48)   13824       ['mixed1[0][0]']
#
#  conv2d_211 (Conv2D)            (None, 25, 25, 96)   55296       ['activation_210[0][0]']
#
#  batch_normalization_208 (Batch  (None, 25, 25, 48)  144         ['conv2d_208[0][0]']
#  Normalization)
#
#  batch_normalization_211 (Batch  (None, 25, 25, 96)  288         ['conv2d_211[0][0]']
#  Normalization)
#
#  activation_208 (Activation)    (None, 25, 25, 48)   0           ['batch_normalization_208[0][0]']
#
#  activation_211 (Activation)    (None, 25, 25, 96)   0           ['batch_normalization_211[0][0]']
#
#  average_pooling2d_20 (AverageP  (None, 25, 25, 288)  0          ['mixed1[0][0]']
#  ooling2D)
#
#  conv2d_207 (Conv2D)            (None, 25, 25, 64)   18432       ['mixed1[0][0]']
#
#  conv2d_209 (Conv2D)            (None, 25, 25, 64)   76800       ['activation_208[0][0]']
#
#  conv2d_212 (Conv2D)            (None, 25, 25, 96)   82944       ['activation_211[0][0]']
#
#  conv2d_213 (Conv2D)            (None, 25, 25, 64)   18432       ['average_pooling2d_20[0][0]']
#
#  batch_normalization_207 (Batch  (None, 25, 25, 64)  192         ['conv2d_207[0][0]']
#  Normalization)
#
#  batch_normalization_209 (Batch  (None, 25, 25, 64)  192         ['conv2d_209[0][0]']
#  Normalization)
#
#  batch_normalization_212 (Batch  (None, 25, 25, 96)  288         ['conv2d_212[0][0]']
#  Normalization)
#
#  batch_normalization_213 (Batch  (None, 25, 25, 64)  192         ['conv2d_213[0][0]']
#  Normalization)
#
#  activation_207 (Activation)    (None, 25, 25, 64)   0           ['batch_normalization_207[0][0]']
#
#  activation_209 (Activation)    (None, 25, 25, 64)   0           ['batch_normalization_209[0][0]']
#
#  activation_212 (Activation)    (None, 25, 25, 96)   0           ['batch_normalization_212[0][0]']
#
#  activation_213 (Activation)    (None, 25, 25, 64)   0           ['batch_normalization_213[0][0]']
#
#  mixed2 (Concatenate)           (None, 25, 25, 288)  0           ['activation_207[0][0]',
#                                                                   'activation_209[0][0]',
#                                                                   'activation_212[0][0]',
#                                                                   'activation_213[0][0]']
#
#  conv2d_215 (Conv2D)            (None, 25, 25, 64)   18432       ['mixed2[0][0]']
#
#  batch_normalization_215 (Batch  (None, 25, 25, 64)  192         ['conv2d_215[0][0]']
#  Normalization)
#
#  activation_215 (Activation)    (None, 25, 25, 64)   0           ['batch_normalization_215[0][0]']
#
#  conv2d_216 (Conv2D)            (None, 25, 25, 96)   55296       ['activation_215[0][0]']
#
#  batch_normalization_216 (Batch  (None, 25, 25, 96)  288         ['conv2d_216[0][0]']
#  Normalization)
#
#  activation_216 (Activation)    (None, 25, 25, 96)   0           ['batch_normalization_216[0][0]']
#
#  conv2d_214 (Conv2D)            (None, 12, 12, 384)  995328      ['mixed2[0][0]']
#
#  conv2d_217 (Conv2D)            (None, 12, 12, 96)   82944       ['activation_216[0][0]']
#
#  batch_normalization_214 (Batch  (None, 12, 12, 384)  1152       ['conv2d_214[0][0]']
#  Normalization)
#
#  batch_normalization_217 (Batch  (None, 12, 12, 96)  288         ['conv2d_217[0][0]']
#  Normalization)
#
#  activation_214 (Activation)    (None, 12, 12, 384)  0           ['batch_normalization_214[0][0]']
#
#  activation_217 (Activation)    (None, 12, 12, 96)   0           ['batch_normalization_217[0][0]']
#
#  max_pooling2d_10 (MaxPooling2D  (None, 12, 12, 288)  0          ['mixed2[0][0]']
#  )
#
#  mixed3 (Concatenate)           (None, 12, 12, 768)  0           ['activation_214[0][0]',
#                                                                   'activation_217[0][0]',
#                                                                   'max_pooling2d_10[0][0]']
#
#  conv2d_222 (Conv2D)            (None, 12, 12, 128)  98304       ['mixed3[0][0]']
#
#  batch_normalization_222 (Batch  (None, 12, 12, 128)  384        ['conv2d_222[0][0]']
#  Normalization)
#
#  activation_222 (Activation)    (None, 12, 12, 128)  0           ['batch_normalization_222[0][0]']
#
#  conv2d_223 (Conv2D)            (None, 12, 12, 128)  114688      ['activation_222[0][0]']
#
#  batch_normalization_223 (Batch  (None, 12, 12, 128)  384        ['conv2d_223[0][0]']
#  Normalization)
#
#  activation_223 (Activation)    (None, 12, 12, 128)  0           ['batch_normalization_223[0][0]']
#
#  conv2d_219 (Conv2D)            (None, 12, 12, 128)  98304       ['mixed3[0][0]']
#
#  conv2d_224 (Conv2D)            (None, 12, 12, 128)  114688      ['activation_223[0][0]']
#
#  batch_normalization_219 (Batch  (None, 12, 12, 128)  384        ['conv2d_219[0][0]']
#  Normalization)
#
#  batch_normalization_224 (Batch  (None, 12, 12, 128)  384        ['conv2d_224[0][0]']
#  Normalization)
#
#  activation_219 (Activation)    (None, 12, 12, 128)  0           ['batch_normalization_219[0][0]']
#
#  activation_224 (Activation)    (None, 12, 12, 128)  0           ['batch_normalization_224[0][0]']
#
#  conv2d_220 (Conv2D)            (None, 12, 12, 128)  114688      ['activation_219[0][0]']
#
#  conv2d_225 (Conv2D)            (None, 12, 12, 128)  114688      ['activation_224[0][0]']
#
#  batch_normalization_220 (Batch  (None, 12, 12, 128)  384        ['conv2d_220[0][0]']
#  Normalization)
#
#  batch_normalization_225 (Batch  (None, 12, 12, 128)  384        ['conv2d_225[0][0]']
#  Normalization)
#
#  activation_220 (Activation)    (None, 12, 12, 128)  0           ['batch_normalization_220[0][0]']
#
#  activation_225 (Activation)    (None, 12, 12, 128)  0           ['batch_normalization_225[0][0]']
#
#  average_pooling2d_21 (AverageP  (None, 12, 12, 768)  0          ['mixed3[0][0]']
#  ooling2D)
#
#  conv2d_218 (Conv2D)            (None, 12, 12, 192)  147456      ['mixed3[0][0]']
#
#  conv2d_221 (Conv2D)            (None, 12, 12, 192)  172032      ['activation_220[0][0]']
#
#  conv2d_226 (Conv2D)            (None, 12, 12, 192)  172032      ['activation_225[0][0]']
#
#  conv2d_227 (Conv2D)            (None, 12, 12, 192)  147456      ['average_pooling2d_21[0][0]']
#
#  batch_normalization_218 (Batch  (None, 12, 12, 192)  576        ['conv2d_218[0][0]']
#  Normalization)
#
#  batch_normalization_221 (Batch  (None, 12, 12, 192)  576        ['conv2d_221[0][0]']
#  Normalization)
#
#  batch_normalization_226 (Batch  (None, 12, 12, 192)  576        ['conv2d_226[0][0]']
#  Normalization)
#
#  batch_normalization_227 (Batch  (None, 12, 12, 192)  576        ['conv2d_227[0][0]']
#  Normalization)
#
#  activation_218 (Activation)    (None, 12, 12, 192)  0           ['batch_normalization_218[0][0]']
#
#  activation_221 (Activation)    (None, 12, 12, 192)  0           ['batch_normalization_221[0][0]']
#
#  activation_226 (Activation)    (None, 12, 12, 192)  0           ['batch_normalization_226[0][0]']
#
#  activation_227 (Activation)    (None, 12, 12, 192)  0           ['batch_normalization_227[0][0]']
#
#  mixed4 (Concatenate)           (None, 12, 12, 768)  0           ['activation_218[0][0]',
#                                                                   'activation_221[0][0]',
#                                                                   'activation_226[0][0]',
#                                                                   'activation_227[0][0]']
#
#  conv2d_232 (Conv2D)            (None, 12, 12, 160)  122880      ['mixed4[0][0]']
#
#  batch_normalization_232 (Batch  (None, 12, 12, 160)  480        ['conv2d_232[0][0]']
#  Normalization)
#
#  activation_232 (Activation)    (None, 12, 12, 160)  0           ['batch_normalization_232[0][0]']
#
#  conv2d_233 (Conv2D)            (None, 12, 12, 160)  179200      ['activation_232[0][0]']
#
#  batch_normalization_233 (Batch  (None, 12, 12, 160)  480        ['conv2d_233[0][0]']
#  Normalization)
#
#  activation_233 (Activation)    (None, 12, 12, 160)  0           ['batch_normalization_233[0][0]']
#
#  conv2d_229 (Conv2D)            (None, 12, 12, 160)  122880      ['mixed4[0][0]']
#
#  conv2d_234 (Conv2D)            (None, 12, 12, 160)  179200      ['activation_233[0][0]']
#
#  batch_normalization_229 (Batch  (None, 12, 12, 160)  480        ['conv2d_229[0][0]']
#  Normalization)
#
#  batch_normalization_234 (Batch  (None, 12, 12, 160)  480        ['conv2d_234[0][0]']
#  Normalization)
#
#  activation_229 (Activation)    (None, 12, 12, 160)  0           ['batch_normalization_229[0][0]']
#
#  activation_234 (Activation)    (None, 12, 12, 160)  0           ['batch_normalization_234[0][0]']
#
#  conv2d_230 (Conv2D)            (None, 12, 12, 160)  179200      ['activation_229[0][0]']
#
#  conv2d_235 (Conv2D)            (None, 12, 12, 160)  179200      ['activation_234[0][0]']
#
#  batch_normalization_230 (Batch  (None, 12, 12, 160)  480        ['conv2d_230[0][0]']
#  Normalization)
#
#  batch_normalization_235 (Batch  (None, 12, 12, 160)  480        ['conv2d_235[0][0]']
#  Normalization)
#
#  activation_230 (Activation)    (None, 12, 12, 160)  0           ['batch_normalization_230[0][0]']
#
#  activation_235 (Activation)    (None, 12, 12, 160)  0           ['batch_normalization_235[0][0]']
#
#  average_pooling2d_22 (AverageP  (None, 12, 12, 768)  0          ['mixed4[0][0]']
#  ooling2D)
#
#  conv2d_228 (Conv2D)            (None, 12, 12, 192)  147456      ['mixed4[0][0]']
#
#  conv2d_231 (Conv2D)            (None, 12, 12, 192)  215040      ['activation_230[0][0]']
#
#  conv2d_236 (Conv2D)            (None, 12, 12, 192)  215040      ['activation_235[0][0]']
#
#  conv2d_237 (Conv2D)            (None, 12, 12, 192)  147456      ['average_pooling2d_22[0][0]']
#
#  batch_normalization_228 (Batch  (None, 12, 12, 192)  576        ['conv2d_228[0][0]']
#  Normalization)
#
#  batch_normalization_231 (Batch  (None, 12, 12, 192)  576        ['conv2d_231[0][0]']
#  Normalization)
#
#  batch_normalization_236 (Batch  (None, 12, 12, 192)  576        ['conv2d_236[0][0]']
#  Normalization)
#
#  batch_normalization_237 (Batch  (None, 12, 12, 192)  576        ['conv2d_237[0][0]']
#  Normalization)
#
#  activation_228 (Activation)    (None, 12, 12, 192)  0           ['batch_normalization_228[0][0]']
#
#  activation_231 (Activation)    (None, 12, 12, 192)  0           ['batch_normalization_231[0][0]']
#
#  activation_236 (Activation)    (None, 12, 12, 192)  0           ['batch_normalization_236[0][0]']
#
#  activation_237 (Activation)    (None, 12, 12, 192)  0           ['batch_normalization_237[0][0]']
#
#  mixed5 (Concatenate)           (None, 12, 12, 768)  0           ['activation_228[0][0]',
#                                                                   'activation_231[0][0]',
#                                                                   'activation_236[0][0]',
#                                                                   'activation_237[0][0]']
#
#  conv2d_242 (Conv2D)            (None, 12, 12, 160)  122880      ['mixed5[0][0]']
#
#  batch_normalization_242 (Batch  (None, 12, 12, 160)  480        ['conv2d_242[0][0]']
#  Normalization)
#
#  activation_242 (Activation)    (None, 12, 12, 160)  0           ['batch_normalization_242[0][0]']
#
#  conv2d_243 (Conv2D)            (None, 12, 12, 160)  179200      ['activation_242[0][0]']
#
#  batch_normalization_243 (Batch  (None, 12, 12, 160)  480        ['conv2d_243[0][0]']
#  Normalization)
#
#  activation_243 (Activation)    (None, 12, 12, 160)  0           ['batch_normalization_243[0][0]']
#
#  conv2d_239 (Conv2D)            (None, 12, 12, 160)  122880      ['mixed5[0][0]']
#
#  conv2d_244 (Conv2D)            (None, 12, 12, 160)  179200      ['activation_243[0][0]']
#
#  batch_normalization_239 (Batch  (None, 12, 12, 160)  480        ['conv2d_239[0][0]']
#  Normalization)
#
#  batch_normalization_244 (Batch  (None, 12, 12, 160)  480        ['conv2d_244[0][0]']
#  Normalization)
#
#  activation_239 (Activation)    (None, 12, 12, 160)  0           ['batch_normalization_239[0][0]']
#
#  activation_244 (Activation)    (None, 12, 12, 160)  0           ['batch_normalization_244[0][0]']
#
#  conv2d_240 (Conv2D)            (None, 12, 12, 160)  179200      ['activation_239[0][0]']
#
#  conv2d_245 (Conv2D)            (None, 12, 12, 160)  179200      ['activation_244[0][0]']
#
#  batch_normalization_240 (Batch  (None, 12, 12, 160)  480        ['conv2d_240[0][0]']
#  Normalization)
#
#  batch_normalization_245 (Batch  (None, 12, 12, 160)  480        ['conv2d_245[0][0]']
#  Normalization)
#
#  activation_240 (Activation)    (None, 12, 12, 160)  0           ['batch_normalization_240[0][0]']
#
#  activation_245 (Activation)    (None, 12, 12, 160)  0           ['batch_normalization_245[0][0]']
#
#  average_pooling2d_23 (AverageP  (None, 12, 12, 768)  0          ['mixed5[0][0]']
#  ooling2D)
#
#  conv2d_238 (Conv2D)            (None, 12, 12, 192)  147456      ['mixed5[0][0]']
#
#  conv2d_241 (Conv2D)            (None, 12, 12, 192)  215040      ['activation_240[0][0]']
#
#  conv2d_246 (Conv2D)            (None, 12, 12, 192)  215040      ['activation_245[0][0]']
#
#  conv2d_247 (Conv2D)            (None, 12, 12, 192)  147456      ['average_pooling2d_23[0][0]']
#
#  batch_normalization_238 (Batch  (None, 12, 12, 192)  576        ['conv2d_238[0][0]']
#  Normalization)
#
#  batch_normalization_241 (Batch  (None, 12, 12, 192)  576        ['conv2d_241[0][0]']
#  Normalization)
#
#  batch_normalization_246 (Batch  (None, 12, 12, 192)  576        ['conv2d_246[0][0]']
#  Normalization)
#
#  batch_normalization_247 (Batch  (None, 12, 12, 192)  576        ['conv2d_247[0][0]']
#  Normalization)
#
#  activation_238 (Activation)    (None, 12, 12, 192)  0           ['batch_normalization_238[0][0]']
#
#  activation_241 (Activation)    (None, 12, 12, 192)  0           ['batch_normalization_241[0][0]']
#
#  activation_246 (Activation)    (None, 12, 12, 192)  0           ['batch_normalization_246[0][0]']
#
# ...
#
#  conv2d_267 (Conv2D)            (None, 5, 5, 384)    442368      ['activation_265[0][0]']
#
#  conv2d_270 (Conv2D)            (None, 5, 5, 384)    442368      ['activation_269[0][0]']
#
#  conv2d_271 (Conv2D)            (None, 5, 5, 384)    442368      ['activation_269[0][0]']
#
#  average_pooling2d_25 (AverageP  (None, 5, 5, 1280)  0           ['mixed8[0][0]']
#  ooling2D)
#
#  conv2d_264 (Conv2D)            (None, 5, 5, 320)    409600      ['mixed8[0][0]']
#
#  batch_normalization_266 (Batch  (None, 5, 5, 384)   1152        ['conv2d_266[0][0]']
#  Normalization)
#
#  batch_normalization_267 (Batch  (None, 5, 5, 384)   1152        ['conv2d_267[0][0]']
#  Normalization)
#
#  batch_normalization_270 (Batch  (None, 5, 5, 384)   1152        ['conv2d_270[0][0]']
#  Normalization)
#
#  batch_normalization_271 (Batch  (None, 5, 5, 384)   1152        ['conv2d_271[0][0]']
#  Normalization)
#
#  conv2d_272 (Conv2D)            (None, 5, 5, 192)    245760      ['average_pooling2d_25[0][0]']
#
#  batch_normalization_264 (Batch  (None, 5, 5, 320)   960         ['conv2d_264[0][0]']
#  Normalization)
#
#  activation_266 (Activation)    (None, 5, 5, 384)    0           ['batch_normalization_266[0][0]']
#
#  activation_267 (Activation)    (None, 5, 5, 384)    0           ['batch_normalization_267[0][0]']
#
#  activation_270 (Activation)    (None, 5, 5, 384)    0           ['batch_normalization_270[0][0]']
#
#  activation_271 (Activation)    (None, 5, 5, 384)    0           ['batch_normalization_271[0][0]']
#
#  batch_normalization_272 (Batch  (None, 5, 5, 192)   576         ['conv2d_272[0][0]']
#  Normalization)
#
#  activation_264 (Activation)    (None, 5, 5, 320)    0           ['batch_normalization_264[0][0]']
#
#  mixed9_0 (Concatenate)         (None, 5, 5, 768)    0           ['activation_266[0][0]',
#                                                                   'activation_267[0][0]']
#
#  concatenate_4 (Concatenate)    (None, 5, 5, 768)    0           ['activation_270[0][0]',
#                                                                   'activation_271[0][0]']
#
#  activation_272 (Activation)    (None, 5, 5, 192)    0           ['batch_normalization_272[0][0]']
#
#  mixed9 (Concatenate)           (None, 5, 5, 2048)   0           ['activation_264[0][0]',
#                                                                   'mixed9_0[0][0]',
#                                                                   'concatenate_4[0][0]',
#                                                                   'activation_272[0][0]']
#
#  conv2d_277 (Conv2D)            (None, 5, 5, 448)    917504      ['mixed9[0][0]']
#
#  batch_normalization_277 (Batch  (None, 5, 5, 448)   1344        ['conv2d_277[0][0]']
#  Normalization)
#
#  activation_277 (Activation)    (None, 5, 5, 448)    0           ['batch_normalization_277[0][0]']
#
#  conv2d_274 (Conv2D)            (None, 5, 5, 384)    786432      ['mixed9[0][0]']
#
#  conv2d_278 (Conv2D)            (None, 5, 5, 384)    1548288     ['activation_277[0][0]']
#
#  batch_normalization_274 (Batch  (None, 5, 5, 384)   1152        ['conv2d_274[0][0]']
#  Normalization)
#
#  batch_normalization_278 (Batch  (None, 5, 5, 384)   1152        ['conv2d_278[0][0]']
#  Normalization)
#
#  activation_274 (Activation)    (None, 5, 5, 384)    0           ['batch_normalization_274[0][0]']
#
#  activation_278 (Activation)    (None, 5, 5, 384)    0           ['batch_normalization_278[0][0]']
#
#  conv2d_275 (Conv2D)            (None, 5, 5, 384)    442368      ['activation_274[0][0]']
#
#  conv2d_276 (Conv2D)            (None, 5, 5, 384)    442368      ['activation_274[0][0]']
#
#  conv2d_279 (Conv2D)            (None, 5, 5, 384)    442368      ['activation_278[0][0]']
#
#  conv2d_280 (Conv2D)            (None, 5, 5, 384)    442368      ['activation_278[0][0]']
#
#  average_pooling2d_26 (AverageP  (None, 5, 5, 2048)  0           ['mixed9[0][0]']
#  ooling2D)
#
#  conv2d_273 (Conv2D)            (None, 5, 5, 320)    655360      ['mixed9[0][0]']
#
#  batch_normalization_275 (Batch  (None, 5, 5, 384)   1152        ['conv2d_275[0][0]']
#  Normalization)
#
#  batch_normalization_276 (Batch  (None, 5, 5, 384)   1152        ['conv2d_276[0][0]']
#  Normalization)
#
#  batch_normalization_279 (Batch  (None, 5, 5, 384)   1152        ['conv2d_279[0][0]']
#  Normalization)
#
#  batch_normalization_280 (Batch  (None, 5, 5, 384)   1152        ['conv2d_280[0][0]']
#  Normalization)
#
#  conv2d_281 (Conv2D)            (None, 5, 5, 192)    393216      ['average_pooling2d_26[0][0]']
#
#  batch_normalization_273 (Batch  (None, 5, 5, 320)   960         ['conv2d_273[0][0]']
#  Normalization)
#
#  activation_275 (Activation)    (None, 5, 5, 384)    0           ['batch_normalization_275[0][0]']
#
#  activation_276 (Activation)    (None, 5, 5, 384)    0           ['batch_normalization_276[0][0]']
#
#  activation_279 (Activation)    (None, 5, 5, 384)    0           ['batch_normalization_279[0][0]']
#
#  activation_280 (Activation)    (None, 5, 5, 384)    0           ['batch_normalization_280[0][0]']
#
#  batch_normalization_281 (Batch  (None, 5, 5, 192)   576         ['conv2d_281[0][0]']
#  Normalization)
#
#  activation_273 (Activation)    (None, 5, 5, 320)    0           ['batch_normalization_273[0][0]']
#
#  mixed9_1 (Concatenate)         (None, 5, 5, 768)    0           ['activation_275[0][0]',
#                                                                   'activation_276[0][0]']
#
#  concatenate_5 (Concatenate)    (None, 5, 5, 768)    0           ['activation_279[0][0]',
#                                                                   'activation_280[0][0]']
#
#  activation_281 (Activation)    (None, 5, 5, 192)    0           ['batch_normalization_281[0][0]']
#
#  mixed10 (Concatenate)          (None, 5, 5, 2048)   0           ['activation_273[0][0]',
#                                                                   'mixed9_1[0][0]',
#                                                                   'concatenate_5[0][0]',
#                                                                   'activation_281[0][0]']
#
#  conv2d_282 (Conv2D)            (None, 3, 3, 32)     589856      ['mixed10[0][0]']
#
#  max_pooling2d_12 (MaxPooling2D  (None, 1, 1, 32)    0           ['conv2d_282[0][0]']
#  )
#
#  batch_normalization_282 (Batch  (None, 1, 1, 32)    128         ['max_pooling2d_12[0][0]']
#  Normalization)
#
#  flatten_1 (Flatten)            (None, 32)           0           ['batch_normalization_282[0][0]']
#
#  dense_4 (Dense)                (None, 512)          16896       ['flatten_1[0][0]']
#
#  dropout_1 (Dropout)            (None, 512)          0           ['dense_4[0][0]']
#
#  batch_normalization_283 (Batch  (None, 512)         2048        ['dropout_1[0][0]']
#  Normalization)
#
#  dense_5 (Dense)                (None, 256)          131328      ['batch_normalization_283[0][0]']
#
#  dropout_2 (Dropout)            (None, 256)          0           ['dense_5[0][0]']
#
#  batch_normalization_284 (Batch  (None, 256)         1024        ['dropout_2[0][0]']
#  Normalization)
#
#  dense_6 (Dense)                (None, 13)           3341        ['batch_normalization_284[0][0]']
#
# ==================================================================================================
# Total params: 22,547,405
# Trainable params: 21,983,101
# Non-trainable params: 564,304
# __________________________________________________________________________________________________

# %%
for layer in model_.layers:
    print(layer, layer.trainable)
# Out:
# <keras.engine.input_layer.InputLayer object at 0x000001FB36EE4E50> False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001FB78BB4520> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001FB37363C40> False
# <keras.layers.core.activation.Activation object at 0x000001FB10CA0B20> False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001FB36EE4400> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001FB0EEBA250> False
# <keras.layers.core.activation.Activation object at 0x000001FB0EEC5A60> False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001FB0EEC5A90> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001FB0EED3F10> False
# <keras.layers.core.activation.Activation object at 0x000001FB0EED34F0> False
# <keras.layers.pooling.max_pooling2d.MaxPooling2D object at 0x000001FB0EEC6070> False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001FB0C872610> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001FB0EEC8340> False
# <keras.layers.core.activation.Activation object at 0x000001FB0EEC88B0> False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001FB0EEAE520> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001FB0EEAA9A0> False
# <keras.layers.core.activation.Activation object at 0x000001FB0EEAAA90> False
# <keras.layers.pooling.max_pooling2d.MaxPooling2D object at 0x000001FB0EEC69D0> False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001FB0C124E20> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001FB0C124A60> False
# <keras.layers.core.activation.Activation object at 0x000001FB0C132940> False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001FB0EEAE9A0> False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001FB0C12BE80> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001FB0EEAB6A0> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001FB0C12BD00> False
# <keras.layers.core.activation.Activation object at 0x000001FB0EEABC10> False
# <keras.layers.core.activation.Activation object at 0x000001FB0C1414C0> False
# <keras.layers.pooling.average_pooling2d.AveragePooling2D object at 0x000001FB0C14D550> False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001FB0EEC6760> False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001FB0EEA6610> False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001FB0C141F40> False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001FB0C132970> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001FB0EEB0B20> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001FB0C127BE0> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001FB0C1395E0> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001FB0C147490> False
# <keras.layers.core.activation.Activation object at 0x000001FB0EEB0FD0> False
# <keras.layers.core.activation.Activation object at 0x000001FB0C127DF0> False
# <keras.layers.core.activation.Activation object at 0x000001FB0C14D1C0> False
# <keras.layers.core.activation.Activation object at 0x000001FB0C156BE0> False
# <keras.layers.merging.concatenate.Concatenate object at 0x000001FB0C1567F0> False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001FB0C14D220> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001FB0C15F730> False
# <keras.layers.core.activation.Activation object at 0x000001FB0C16BE50> False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001FB0C12BBB0> False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001FB0C16BD90> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001FB0C124280> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001FB0C16B520> False
# <keras.layers.core.activation.Activation object at 0x000001FB0EED3D90> False
# <keras.layers.core.activation.Activation object at 0x000001FB0C178A30> False
# <keras.layers.pooling.average_pooling2d.AveragePooling2D object at 0x000001FB0C186850> False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001FB0C14D280> False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001FB0EEAA790> True
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001FB0C178970> True
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001FB0C186820> True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001FB0C1325B0> True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001FB0EEB0CA0> True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001FB0C178E80> True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001FB0C17DE80> True
# <keras.layers.core.activation.Activation object at 0x000001FB0C12BD90> True
# <keras.layers.core.activation.Activation object at 0x000001FB0C147250> True
# <keras.layers.core.activation.Activation object at 0x000001FB0C1864C0> True
# <keras.layers.core.activation.Activation object at 0x000001FB0C18D5E0> True
# <keras.layers.merging.concatenate.Concatenate object at 0x000001FB0C18DB80> True
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001FB0C1BCB50> True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001FB0C1AC760> True
# <keras.layers.core.activation.Activation object at 0x000001FB0C1CC6A0> True
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001FB0C1A0370> True
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001FB0C1CC730> True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001FB0C1963D0> True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001FB0C1C4CD0> True
# <keras.layers.core.activation.Activation object at 0x000001FB0C1AC580> True
# <keras.layers.core.activation.Activation object at 0x000001FB0C1D1850> True
# <keras.layers.pooling.average_pooling2d.AveragePooling2D object at 0x000001FB0C1A0A30> True
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001FB0C178DC0> True
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001FB0C1ACF70> True
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001FB0C1D1CD0> True
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001FB0C1A0D60> True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001FB0C17DCD0> True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001FB0C18DE50> True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001FB0C1BCCD0> True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001FB0C1C43A0> True
# <keras.layers.core.activation.Activation object at 0x000001FB0C1A0F10> True
# <keras.layers.core.activation.Activation object at 0x000001FB0C1BCC10> True
# <keras.layers.core.activation.Activation object at 0x000001FB0C1D1A30> True
# <keras.layers.core.activation.Activation object at 0x000001FB0C1B4370> True
# <keras.layers.merging.concatenate.Concatenate object at 0x000001FB0C132FA0> True
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001FB0C147DC0> True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001FB0C1B4F70> True
# <keras.layers.core.activation.Activation object at 0x000001FB0C186AC0> True
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001FB0C186BE0> True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001FB0EEB0F10> True
# <keras.layers.core.activation.Activation object at 0x000001FB0C196340> True
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001FB0C172D90> True
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001FB0C16B250> True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001FB0C172100> True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001FB0C15F8B0> True
# <keras.layers.core.activation.Activation object at 0x000001FB0C1C42B0> True
# <keras.layers.core.activation.Activation object at 0x000001FB0C1EC130> True
# <keras.layers.pooling.max_pooling2d.MaxPooling2D object at 0x000001FB0C1EC2E0> True
# <keras.layers.merging.concatenate.Concatenate object at 0x000001FB0C174340> True
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001FB0C21FCA0> True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001FB0C21FC40> True
# <keras.layers.core.activation.Activation object at 0x000001FB0C2300D0> True
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001FB0C230880> True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001FB0C21FC70> True
# <keras.layers.core.activation.Activation object at 0x000001FB0C2413D0> True
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001FB0C1EC460> True
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001FB0C241460> True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001FB0C1FEB50> True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001FB0C230160> True
# <keras.layers.core.activation.Activation object at 0x000001FB0C2039D0> True
# <keras.layers.core.activation.Activation object at 0x000001FB0C241DC0> True
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001FB0C18B040> True
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001FB0C219F70> True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001FB0C20BCA0> True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001FB0ADFCCD0> True
# <keras.layers.core.activation.Activation object at 0x000001FB0C203130> True
# <keras.layers.core.activation.Activation object at 0x000001FB0ADCA4F0> True
# <keras.layers.pooling.average_pooling2d.AveragePooling2D object at 0x000001FB30931A60> True
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001FB0C18B4F0> True
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001FB0C2107C0> True
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001FB0AE29A00> True
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001FB0ADA6520> True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001FB0C1F3B50> True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001FB0C20BA90> True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001FB30979E20> True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001FB0AE223D0> True
# <keras.layers.core.activation.Activation object at 0x000001FB0C1F3D00> True
# <keras.layers.core.activation.Activation object at 0x000001FB0C21FD60> True
# <keras.layers.core.activation.Activation object at 0x000001FB0AE376D0> True
# <keras.layers.core.activation.Activation object at 0x000001FB0BF9B6D0> True
# <keras.layers.merging.concatenate.Concatenate object at 0x000001FB309C8A30> True
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001FB78ABAF40> True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001FB0BE2DA90> True
# <keras.layers.core.activation.Activation object at 0x000001FB0EA66E80> True
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001FB0C903910> True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001FB306BBAF0> True
# <keras.layers.core.activation.Activation object at 0x000001FB0C3382E0> True
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001FB0C003CA0> True
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001FB0C210610> True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001FB0C061CD0> True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001FB0BE27E20> True
# <keras.layers.core.activation.Activation object at 0x000001FB0BEBFE50> True
# <keras.layers.core.activation.Activation object at 0x000001FB0C1CCBE0> True
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001FB0C061FD0> True
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001FB0C66C8E0> True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001FB0BE76FA0> True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001FB37160490> True
# <keras.layers.core.activation.Activation object at 0x000001FB0AD55D60> True
# <keras.layers.core.activation.Activation object at 0x000001FB11755880> True
# <keras.layers.pooling.average_pooling2d.AveragePooling2D object at 0x000001FB373635E0> True
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001FB0BFAF5B0> True
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001FB78A73400> True
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001FB78BA66D0> True
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001FB3737B460> True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001FB0BF8C1F0> True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001FB0BE51100> True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001FB0EA41730> True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001FB0E9A6790> True
# <keras.layers.core.activation.Activation object at 0x000001FB36E4FBB0> True
# <keras.layers.core.activation.Activation object at 0x000001FB309BF880> True
# <keras.layers.core.activation.Activation object at 0x000001FB37158DF0> True
# <keras.layers.core.activation.Activation object at 0x000001FB0C8BA910> True
# <keras.layers.merging.concatenate.Concatenate object at 0x000001FB0BE27190> True
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001FB375F9E20> True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001FB375EC970> True
# <keras.layers.core.activation.Activation object at 0x000001FB375E4730> True
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001FB375ECD30> True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001FB375D8EB0> True
# <keras.layers.core.activation.Activation object at 0x000001FB375D1F10> True
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001FB0C0030A0> True
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001FB375D8910> True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001FB0ADD1B50> True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001FB375C46D0> True
# <keras.layers.core.activation.Activation object at 0x000001FB0AD89820> True
# <keras.layers.core.activation.Activation object at 0x000001FB375B0E50> True
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001FB0AD67520> True
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001FB375B0790> True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001FB3761A490> True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001FB375AA580> True
# <keras.layers.core.activation.Activation object at 0x000001FB37610D60> True
# <keras.layers.core.activation.Activation object at 0x000001FB3759ED90> True
# <keras.layers.pooling.average_pooling2d.AveragePooling2D object at 0x000001FB37588640> True
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001FB36E3E4F0> True
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001FB37610820> True
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001FB375AAAC0> True
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001FB37592D60> True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001FB0AE22EB0> True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001FB3760C1C0> True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001FB37592760> True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001FB37578D60> True
# <keras.layers.core.activation.Activation object at 0x000001FB78B470A0> True
# <keras.layers.core.activation.Activation object at 0x000001FB375F9FD0> True
# <keras.layers.core.activation.Activation object at 0x000001FB37588670> True
# <keras.layers.core.activation.Activation object at 0x000001FB3756E580> True
# <keras.layers.merging.concatenate.Concatenate object at 0x000001FB3756ED60> True
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001FB37548DC0> True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001FB377F3430> True
# <keras.layers.core.activation.Activation object at 0x000001FB37535FA0> True
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001FB37535910> True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001FB37528AF0> True
# <keras.layers.core.activation.Activation object at 0x000001FB37521D30> True
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001FB37578A60> True
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001FB37528A60> True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001FB37592310> True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001FB37518340> True
# <keras.layers.core.activation.Activation object at 0x000001FB375AA820> True
# <keras.layers.core.activation.Activation object at 0x000001FB37502970> True
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001FB37592C70> True
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001FB37502FD0> True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001FB375F9040> True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001FB37518070> True
# <keras.layers.core.activation.Activation object at 0x000001FB377D49D0> True
# <keras.layers.core.activation.Activation object at 0x000001FB374EE730> True
# <keras.layers.pooling.average_pooling2d.AveragePooling2D object at 0x000001FB374DA4C0> True
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001FB37592DF0> True
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001FB0AE1A490> True
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001FB374EE3D0> True
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001FB374E7D60> True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001FB37559DF0> True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001FB308D0040> True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001FB374E7DF0> True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001FB374CB280> True
# <keras.layers.core.activation.Activation object at 0x000001FB375594C0> True
# <keras.layers.core.activation.Activation object at 0x000001FB0BE6B7F0> True
# <keras.layers.core.activation.Activation object at 0x000001FB374DAFD0> True
# <keras.layers.core.activation.Activation object at 0x000001FB374CBE20> True
# <keras.layers.merging.concatenate.Concatenate object at 0x000001FB374E7BE0> True
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001FB374A3B20> True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001FB37484700> True
# <keras.layers.core.activation.Activation object at 0x000001FB3747ED90> True
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001FB3747E580> True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001FB374A3910> True
# <keras.layers.core.activation.Activation object at 0x000001FB374CFDF0> True
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001FB374C0D30> True
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001FB374DAA90> True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001FB374AB6D0> True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001FB37490670> True
# <keras.layers.core.activation.Activation object at 0x000001FB374ABEB0> True
# <keras.layers.core.activation.Activation object at 0x000001FB0EA41310> True
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001FB374CF610> True
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001FB37553D90> True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001FB374993D0> True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001FB374EEEB0> True
# <keras.layers.core.activation.Activation object at 0x000001FB374995E0> True
# <keras.layers.core.activation.Activation object at 0x000001FB375D17C0> True
# <keras.layers.pooling.max_pooling2d.MaxPooling2D object at 0x000001FB37470EE0> True
# <keras.layers.merging.concatenate.Concatenate object at 0x000001FB37470850> True
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001FB37409FD0> True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001FB373FF730> True
# <keras.layers.core.activation.Activation object at 0x000001FB373FF7C0> True
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001FB37455040> True
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001FB37419D90> True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001FB3743E190> True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001FB373EB2B0> True
# <keras.layers.core.activation.Activation object at 0x000001FB3743ED30> True
# <keras.layers.core.activation.Activation object at 0x000001FB373EBA00> True
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001FB3744DA90> True
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001FB374361F0> True
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001FB373E3040> True
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001FB373F34F0> True
# <keras.layers.pooling.average_pooling2d.AveragePooling2D object at 0x000001FB377FDEE0> True
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001FB3746CFA0> True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001FB37422040> True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001FB37412880> True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001FB373D03A0> True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001FB373C52B0> True
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001FB377FD0A0> True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001FB37460880> True
# <keras.layers.core.activation.Activation object at 0x000001FB37422EE0> True
# <keras.layers.core.activation.Activation object at 0x000001FB37412BE0> True
# <keras.layers.core.activation.Activation object at 0x000001FB373D0040> True
# <keras.layers.core.activation.Activation object at 0x000001FB378094C0> True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001FB37804250> True
# <keras.layers.core.activation.Activation object at 0x000001FB3746CA00> True
# <keras.layers.merging.concatenate.Concatenate object at 0x000001FB37419490> True
# <keras.layers.merging.concatenate.Concatenate object at 0x000001FB373E3FA0> True
# <keras.layers.core.activation.Activation object at 0x000001FB373D0DC0> True
# <keras.layers.merging.concatenate.Concatenate object at 0x000001FB373EB100> True
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001FB373EBA30> True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001FB37387A00> True
# <keras.layers.core.activation.Activation object at 0x000001FB37387DC0> True
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001FB0C241730> True
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001FB37396730> True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001FB374F9820> True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001FB7898D700> True
# <keras.layers.core.activation.Activation object at 0x000001FB0C219370> True
# <keras.layers.core.activation.Activation object at 0x000001FB7898D6D0> True
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001FB3746C580> True
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001FB37470250> True
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001FB7898D070> True
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001FB37396AF0> True
# <keras.layers.pooling.average_pooling2d.AveragePooling2D object at 0x000001FB77546D60> True
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001FB3744D340> True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001FB377E53A0> True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001FB3739E0A0> True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001FB373C5E80> True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001FB789C8790> True
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001FB37834F10> True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001FB373D0370> True
# <keras.layers.core.activation.Activation object at 0x000001FB377E52B0> True
# <keras.layers.core.activation.Activation object at 0x000001FB3739EF70> True
# <keras.layers.core.activation.Activation object at 0x000001FB7896E190> True
# <keras.layers.core.activation.Activation object at 0x000001FB37631D00> True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001FB37626460> True
# <keras.layers.core.activation.Activation object at 0x000001FB375D19D0> True
# <keras.layers.merging.concatenate.Concatenate object at 0x000001FB3739EDC0> True
# <keras.layers.merging.concatenate.Concatenate object at 0x000001FB37631370> True
# <keras.layers.core.activation.Activation object at 0x000001FB376261F0> True
# <keras.layers.merging.concatenate.Concatenate object at 0x000001FB37631C40> True
# <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D object at 0x000001FB775114F0> True
# <keras.layers.core.dense.Dense object at 0x000001FB77511430> True
# <keras.layers.regularization.dropout.Dropout object at 0x000001FB36EF5040> True
# <keras.layers.core.dense.Dense object at 0x000001FB378348B0> True
# <keras.layers.core.dense.Dense object at 0x000001FB37834A90> True

# %%
# compile the model
model_.compile(optimizer=SGD(lr=0.001, momentum=0.9)
                    , loss='categorical_crossentropy'
                    , metrics=['accuracy'])

# %%
from keras.callbacks import ModelCheckpoint, EarlyStopping
es = EarlyStopping(monitor='val_accuracy', min_delta=0, patience=20, verbose=1, mode='auto')
H = model_.fit_generator(train_generator,validation_data=test_generator,epochs=100,verbose=1,callbacks=[es])
# Out:
# C:\Users\Yahya Akel\AppData\Local\Temp\ipykernel_5516\4288076846.py:3: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   H = model_.fit_generator(train_generator,validation_data=test_generator,epochs=100,verbose=1,callbacks=[es])
# Epoch 1/100
#  8/25 [========>.....................] - ETA: 52s - loss: 2.7272 - accuracy: 0.0742
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5516\4288076846.py in <module>
#       1 from keras.callbacks import ModelCheckpoint, EarlyStopping
#       2 es = EarlyStopping(monitor='val_accuracy', min_delta=0, patience=20, verbose=1, mode='auto')
# ----> 3 H = model_.fit_generator(train_generator,validation_data=test_generator,epochs=100,verbose=1,callbacks=[es])
#
# e:\Ana\lib\site-packages\keras\engine\training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    2602             stacklevel=2,
#    2603         )
# -> 2604         return self.fit(
#    2605             generator,
#    2606             steps_per_epoch=steps_per_epoch,
#
# e:\Ana\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# e:\Ana\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1648                         ):
#    1649                             callbacks.on_train_batch_begin(step)
# -> 1650                             tmp_logs = self.train_function(iterator)
#    1651                             if data_handler.should_sync:
#    1652                                 context.async_wait()
#
# e:\Ana\lib\site-packages\tensorflow\python\util\traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# e:\Ana\lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py in __call__(self, *args, **kwds)
#     878
#     879       with OptionalXlaContext(self._jit_compile):
# --> 880         result = self._call(*args, **kwds)
#     881
#     882       new_tracing_count = self.experimental_get_tracing_count()
#
# e:\Ana\lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py in _call(self, *args, **kwds)
#     910       # In this case we have created variables on the first call, so we run the
#     911       # defunned version which is guaranteed to never create variables.
# --> 912       return self._no_variable_creation_fn(*args, **kwds)  # pylint: disable=not-callable
#     913     elif self._variable_creation_fn is not None:
#     914       # Release the lock early so that multiple threads can perform the call
#
# e:\Ana\lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compiler.py in __call__(self, *args, **kwargs)
#     132       (concrete_function,
#     133        filtered_flat_args) = self._maybe_define_function(args, kwargs)
# --> 134     return concrete_function._call_flat(
#     135         filtered_flat_args, captured_inputs=concrete_function.captured_inputs)  # pylint: disable=protected-access
#     136
#
# e:\Ana\lib\site-packages\tensorflow\python\eager\polymorphic_function\monomorphic_function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1743         and executing_eagerly):
#    1744       # No tape is watching; skip to running the function.
# -> 1745       return self._build_call_outputs(self._inference_function.call(
#    1746           ctx, args, cancellation_manager=cancellation_manager))
#    1747     forward_backward = self._select_forward_and_backward_functions(
#
# e:\Ana\lib\site-packages\tensorflow\python\eager\polymorphic_function\monomorphic_function.py in call(self, ctx, args, cancellation_manager)
#     376       with _InterpolateFunctionError(self):
#     377         if cancellation_manager is None:
# --> 378           outputs = execute.execute(
#     379               str(self.signature.name),
#     380               num_outputs=self._num_outputs,
#
# e:\Ana\lib\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      50   try:
#      51     ctx.ensure_initialized()
# ---> 52     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      53                                         inputs, attrs, num_outputs)
#      54   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
from keras.layers import Convolution2D, Dense, Input, Flatten, Dropout, MaxPooling2D, BatchNormalization, GlobalAveragePooling2D, Concatenate
incep = Sequential()
incep.add(pre_trained_model)
incep.add(GlobalAveragePooling2D())
incep.add(Flatten())
incep.add(Dense(512, activation='relu'))
incep.add(Dropout(0.2))
incep.add(Dense(13, activation='softmax'))

# %%
incep.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  inception_v3 (Functional)   (None, 5, 5, 2048)        21802784
#
#  global_average_pooling2d (G  (None, 2048)             0
#  lobalAveragePooling2D)
#
#  flatten (Flatten)           (None, 2048)              0
#
#  dense (Dense)               (None, 512)               1049088
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 13)                6669
#
# =================================================================
# Total params: 22,858,541
# Trainable params: 1,055,757
# Non-trainable params: 21,802,784
# _________________________________________________________________

# %%
for layer in incep.layers:
    print(layer, layer.trainable)
# Out:
# <keras.engine.functional.Functional object at 0x00000201D1B93790> True
# <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D object at 0x00000201D1B9DFD0> True
# <keras.layers.reshaping.flatten.Flatten object at 0x00000201D1B9D8E0> True
# <keras.layers.core.dense.Dense object at 0x00000201D1ECEAF0> True
# <keras.layers.regularization.dropout.Dropout object at 0x00000201D042AEB0> True
# <keras.layers.core.dense.Dense object at 0x00000201D1EA5640> True

# %%
from keras.optimizers import Adam

model_.compile(optimizer=Adam(lr=0.001),loss='categorical_crossentropy',metrics=['accuracy'])
# Out:
# e:\Ana\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:117: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)

# %%
from keras.callbacks import ModelCheckpoint, EarlyStopping
es = EarlyStopping(monitor='val_accuracy', min_delta=0, patience=20, verbose=1, mode='auto')
H = incep.fit_generator(train_generator,validation_data=test_generator,epochs=100,verbose=1,callbacks=[es])
# Out:
# C:\Users\Yahya Akel\AppData\Local\Temp\ipykernel_22220\2247221170.py:3: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   H = incep.fit_generator(train_generator,validation_data=test_generator,epochs=100,verbose=1,callbacks=[es])
# Epoch 1/100
# 25/25 [==============================] - 50s 2s/step - loss: 57.3840 - accuracy: 0.1244 - val_loss: 16.9231 - val_accuracy: 0.2346
# Epoch 2/100
# 25/25 [==============================] - 28s 1s/step - loss: 8.7694 - accuracy: 0.1590 - val_loss: 3.1740 - val_accuracy: 0.1692
# Epoch 3/100
# 25/25 [==============================] - 29s 1s/step - loss: 2.5398 - accuracy: 0.1154 - val_loss: 2.4336 - val_accuracy: 0.1692
# Epoch 4/100
#  4/25 [===>..........................] - ETA: 19s - loss: 2.5061 - accuracy: 0.1016
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22220\2247221170.py in <module>
#       1 from keras.callbacks import ModelCheckpoint, EarlyStopping
#       2 es = EarlyStopping(monitor='val_accuracy', min_delta=0, patience=20, verbose=1, mode='auto')
# ----> 3 H = incep.fit_generator(train_generator,validation_data=test_generator,epochs=100,verbose=1,callbacks=[es])
#
# e:\Ana\lib\site-packages\keras\engine\training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    2602             stacklevel=2,
#    2603         )
# -> 2604         return self.fit(
#    2605             generator,
#    2606             steps_per_epoch=steps_per_epoch,
#
# e:\Ana\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# e:\Ana\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1648                         ):
#    1649                             callbacks.on_train_batch_begin(step)
# -> 1650                             tmp_logs = self.train_function(iterator)
#    1651                             if data_handler.should_sync:
#    1652                                 context.async_wait()
#
# e:\Ana\lib\site-packages\tensorflow\python\util\traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# e:\Ana\lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py in __call__(self, *args, **kwds)
#     878
#     879       with OptionalXlaContext(self._jit_compile):
# --> 880         result = self._call(*args, **kwds)
#     881
#     882       new_tracing_count = self.experimental_get_tracing_count()
#
# e:\Ana\lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py in _call(self, *args, **kwds)
#     910       # In this case we have created variables on the first call, so we run the
#     911       # defunned version which is guaranteed to never create variables.
# --> 912       return self._no_variable_creation_fn(*args, **kwds)  # pylint: disable=not-callable
#     913     elif self._variable_creation_fn is not None:
#     914       # Release the lock early so that multiple threads can perform the call
#
# e:\Ana\lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compiler.py in __call__(self, *args, **kwargs)
#     132       (concrete_function,
#     133        filtered_flat_args) = self._maybe_define_function(args, kwargs)
# --> 134     return concrete_function._call_flat(
#     135         filtered_flat_args, captured_inputs=concrete_function.captured_inputs)  # pylint: disable=protected-access
#     136
#
# e:\Ana\lib\site-packages\tensorflow\python\eager\polymorphic_function\monomorphic_function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1743         and executing_eagerly):
#    1744       # No tape is watching; skip to running the function.
# -> 1745       return self._build_call_outputs(self._inference_function.call(
#    1746           ctx, args, cancellation_manager=cancellation_manager))
#    1747     forward_backward = self._select_forward_and_backward_functions(
#
# e:\Ana\lib\site-packages\tensorflow\python\eager\polymorphic_function\monomorphic_function.py in call(self, ctx, args, cancellation_manager)
#     376       with _InterpolateFunctionError(self):
#     377         if cancellation_manager is None:
# --> 378           outputs = execute.execute(
#     379               str(self.signature.name),
#     380               num_outputs=self._num_outputs,
#
# e:\Ana\lib\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      50   try:
#      51     ctx.ensure_initialized()
# ---> 52     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      53                                         inputs, attrs, num_outputs)
#      54   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
import pickle
with open('model_incep.pkl', 'wb') as file:
      pickle.dump(incep, file)

# %%
# Renders the charts for training accuracy and loss.
import matplotlib.pyplot as plt
def render_training_history(training_history):
    loss = training_history.history['loss']
    val_loss = training_history.history['val_loss']

    accuracy = training_history.history['accuracy']
    val_accuracy = training_history.history['val_accuracy']

    plt.figure(figsize=(14, 4))

    plt.subplot(1, 2, 1)
    plt.title('Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.plot(loss, label='Training set')
    plt.plot(val_loss, label='Test set', linestyle='--')
    plt.legend()
    plt.grid(linestyle='--', linewidth=1, alpha=0.5)

    plt.subplot(1, 2, 2)
    plt.title('Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.plot(accuracy, label='Training set')
    plt.plot(val_accuracy, label='Test set', linestyle='--')
    plt.legend()
    plt.grid(linestyle='--', linewidth=1, alpha=0.5)

    plt.show()

# %%
render_training_history(H)

# %%
history = model_.fit(
    train_generator,
    steps_per_epoch=train_generator.n // train_generator.batch_size,
    epochs=10,
    validation_data=test_generator,
    validation_steps=test_generator.n // test_generator.batch_size)
# Out:
# Epoch 1/10
# 24/24 [==============================] - 34s 1s/step - loss: 100.6146 - accuracy: 0.1016 - val_loss: 29.9200 - val_accuracy: 0.1094
# Epoch 2/10
# 24/24 [==============================] - 28s 1s/step - loss: 14.5599 - accuracy: 0.2059 - val_loss: 8.4499 - val_accuracy: 0.2344
# Epoch 3/10
# 24/24 [==============================] - 28s 1s/step - loss: 5.1948 - accuracy: 0.2794 - val_loss: 5.4076 - val_accuracy: 0.2422
# Epoch 4/10
# 24/24 [==============================] - 28s 1s/step - loss: 3.2310 - accuracy: 0.3048 - val_loss: 4.6588 - val_accuracy: 0.3242
# Epoch 5/10
# 24/24 [==============================] - 28s 1s/step - loss: 2.8087 - accuracy: 0.3476 - val_loss: 3.1663 - val_accuracy: 0.3477
# Epoch 6/10
# 24/24 [==============================] - 29s 1s/step - loss: 2.4627 - accuracy: 0.3476 - val_loss: 2.8149 - val_accuracy: 0.3359
# Epoch 7/10
# 24/24 [==============================] - 30s 1s/step - loss: 2.3994 - accuracy: 0.3703 - val_loss: 3.5852 - val_accuracy: 0.3164
# Epoch 8/10
# 24/24 [==============================] - 29s 1s/step - loss: 2.5103 - accuracy: 0.3663 - val_loss: 3.7432 - val_accuracy: 0.2812
# Epoch 9/10
# 24/24 [==============================] - 29s 1s/step - loss: 2.6074 - accuracy: 0.3463 - val_loss: 2.2455 - val_accuracy: 0.4141
# Epoch 10/10
# 24/24 [==============================] - 29s 1s/step - loss: 2.0639 - accuracy: 0.3890 - val_loss: 3.5950 - val_accuracy: 0.3164

# %%
history = model_.fit(
    train_generator,
    steps_per_epoch=train_generator.n // train_generator.batch_size,
    epochs=10,
    validation_data=test_generator,
    validation_steps=test_generator.n // test_generator.batch_size)
# Out:
# Epoch 1/10
# 24/24 [==============================] - 33s 1s/step - loss: 5.0594 - accuracy: 0.2553 - val_loss: 2.8190 - val_accuracy: 0.2344
# Epoch 2/10
# 24/24 [==============================] - 27s 1s/step - loss: 2.1601 - accuracy: 0.2741 - val_loss: 2.1832 - val_accuracy: 0.3125
# Epoch 3/10
# 24/24 [==============================] - 28s 1s/step - loss: 1.9437 - accuracy: 0.3516 - val_loss: 2.0927 - val_accuracy: 0.3008
# Epoch 4/10
# 24/24 [==============================] - 28s 1s/step - loss: 1.9847 - accuracy: 0.3409 - val_loss: 2.2989 - val_accuracy: 0.2734
# Epoch 5/10
# 24/24 [==============================] - 28s 1s/step - loss: 1.9002 - accuracy: 0.3529 - val_loss: 2.0386 - val_accuracy: 0.3438
# Epoch 6/10
# 24/24 [==============================] - 29s 1s/step - loss: 1.9015 - accuracy: 0.3570 - val_loss: 2.0094 - val_accuracy: 0.3047
# Epoch 7/10
# 24/24 [==============================] - 28s 1s/step - loss: 1.8982 - accuracy: 0.3623 - val_loss: 2.3896 - val_accuracy: 0.2812
# Epoch 8/10
# 24/24 [==============================] - 28s 1s/step - loss: 1.9143 - accuracy: 0.3275 - val_loss: 2.0945 - val_accuracy: 0.3594
# Epoch 9/10
# 24/24 [==============================] - 29s 1s/step - loss: 1.7786 - accuracy: 0.3703 - val_loss: 2.0644 - val_accuracy: 0.3750
# Epoch 10/10
# 24/24 [==============================] - 28s 1s/step - loss: 1.6845 - accuracy: 0.4184 - val_loss: 1.9639 - val_accuracy: 0.3867

# %%
history = model_.fit(
    train_generator,
    steps_per_epoch=train_generator.n // train_generator.batch_size,
    epochs=10,
    validation_data=test_generator,
    validation_steps=test_generator.n // test_generator.batch_size)
# Out:
# Epoch 1/10
# 12/12 [==============================] - 28s 2s/step - loss: 1.7141 - accuracy: 0.3869 - val_loss: 2.1489 - val_accuracy: 0.2930
# Epoch 2/10
# 12/12 [==============================] - 27s 2s/step - loss: 1.6433 - accuracy: 0.4064 - val_loss: 2.2458 - val_accuracy: 0.3477
# Epoch 3/10
# 12/12 [==============================] - 27s 2s/step - loss: 1.7265 - accuracy: 0.4050 - val_loss: 1.9894 - val_accuracy: 0.4141
# Epoch 4/10
# 12/12 [==============================] - 27s 2s/step - loss: 1.5589 - accuracy: 0.4665 - val_loss: 1.9632 - val_accuracy: 0.3711
# Epoch 5/10
# 12/12 [==============================] - 26s 2s/step - loss: 1.5501 - accuracy: 0.4721 - val_loss: 2.0122 - val_accuracy: 0.3672
# Epoch 6/10
# 12/12 [==============================] - 27s 2s/step - loss: 1.5834 - accuracy: 0.4358 - val_loss: 2.1245 - val_accuracy: 0.4141
# Epoch 7/10
# 12/12 [==============================] - 26s 2s/step - loss: 1.5724 - accuracy: 0.4413 - val_loss: 1.7731 - val_accuracy: 0.4180
# Epoch 8/10
# 12/12 [==============================] - 26s 2s/step - loss: 1.4832 - accuracy: 0.4791 - val_loss: 1.8699 - val_accuracy: 0.3672
# Epoch 9/10
# 12/12 [==============================] - 27s 2s/step - loss: 1.4822 - accuracy: 0.4944 - val_loss: 1.9902 - val_accuracy: 0.3867
# Epoch 10/10
# 12/12 [==============================] - 27s 2s/step - loss: 1.5129 - accuracy: 0.4651 - val_loss: 1.7816 - val_accuracy: 0.4336

# %%
history = model_.fit(
    train_generator,
    steps_per_epoch=train_generator.n // train_generator.batch_size,
    epochs=10,
    validation_data=test_generator,
    validation_steps=test_generator.n // test_generator.batch_size)
# Out:
# Epoch 1/10
# 12/12 [==============================] - 27s 2s/step - loss: 1.5084 - accuracy: 0.4777 - val_loss: 1.7014 - val_accuracy: 0.4336
# Epoch 2/10
# 12/12 [==============================] - 27s 2s/step - loss: 1.5521 - accuracy: 0.4860 - val_loss: 1.7426 - val_accuracy: 0.3945
# Epoch 3/10
# 12/12 [==============================] - 27s 2s/step - loss: 1.5801 - accuracy: 0.4511 - val_loss: 1.9999 - val_accuracy: 0.3711
# Epoch 4/10
# 12/12 [==============================] - 27s 2s/step - loss: 1.5412 - accuracy: 0.4455 - val_loss: 1.8919 - val_accuracy: 0.3906
# Epoch 5/10
# 12/12 [==============================] - 27s 2s/step - loss: 1.5454 - accuracy: 0.4595 - val_loss: 2.0228 - val_accuracy: 0.3242
# Epoch 6/10
# 12/12 [==============================] - 27s 2s/step - loss: 1.6069 - accuracy: 0.4232 - val_loss: 1.8288 - val_accuracy: 0.3867
# Epoch 7/10
# 11/12 [==========================>...] - ETA: 1s - loss: 1.5312 - accuracy: 0.4688
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22220\2799865396.py in <module>
# ----> 1 history = model_.fit(
#       2     train_generator,
#       3     steps_per_epoch=train_generator.n // train_generator.batch_size,
#       4     epochs=10,
#       5     validation_data=test_generator,
#
# e:\Ana\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# e:\Ana\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1648                         ):
#    1649                             callbacks.on_train_batch_begin(step)
# -> 1650                             tmp_logs = self.train_function(iterator)
#    1651                             if data_handler.should_sync:
#    1652                                 context.async_wait()
#
# e:\Ana\lib\site-packages\tensorflow\python\util\traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# e:\Ana\lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py in __call__(self, *args, **kwds)
#     878
#     879       with OptionalXlaContext(self._jit_compile):
# --> 880         result = self._call(*args, **kwds)
#     881
#     882       new_tracing_count = self.experimental_get_tracing_count()
#
# e:\Ana\lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py in _call(self, *args, **kwds)
#     910       # In this case we have created variables on the first call, so we run the
#     911       # defunned version which is guaranteed to never create variables.
# --> 912       return self._no_variable_creation_fn(*args, **kwds)  # pylint: disable=not-callable
#     913     elif self._variable_creation_fn is not None:
#     914       # Release the lock early so that multiple threads can perform the call
#
# e:\Ana\lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compiler.py in __call__(self, *args, **kwargs)
#     132       (concrete_function,
#     133        filtered_flat_args) = self._maybe_define_function(args, kwargs)
# --> 134     return concrete_function._call_flat(
#     135         filtered_flat_args, captured_inputs=concrete_function.captured_inputs)  # pylint: disable=protected-access
#     136
#
# e:\Ana\lib\site-packages\tensorflow\python\eager\polymorphic_function\monomorphic_function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1743         and executing_eagerly):
#    1744       # No tape is watching; skip to running the function.
# -> 1745       return self._build_call_outputs(self._inference_function.call(
#    1746           ctx, args, cancellation_manager=cancellation_manager))
#    1747     forward_backward = self._select_forward_and_backward_functions(
#
# e:\Ana\lib\site-packages\tensorflow\python\eager\polymorphic_function\monomorphic_function.py in call(self, ctx, args, cancellation_manager)
#     376       with _InterpolateFunctionError(self):
#     377         if cancellation_manager is None:
# --> 378           outputs = execute.execute(
#     379               str(self.signature.name),
#     380               num_outputs=self._num_outputs,
#
# e:\Ana\lib\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      50   try:
#      51     ctx.ensure_initialized()
# ---> 52     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      53                                         inputs, attrs, num_outputs)
#      54   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
history = model_.fit(
    train_generator,
    steps_per_epoch=train_generator.n // train_generator.batch_size,
    epochs=10,
    validation_data=test_generator,
    validation_steps=test_generator.n // test_generator.batch_size)
# Out:
# Epoch 1/10
# 12/12 [==============================] - 32s 2s/step - loss: 1.4242 - accuracy: 0.5084 - val_loss: 1.7974 - val_accuracy: 0.3828
# Epoch 2/10
# 12/12 [==============================] - 27s 2s/step - loss: 1.3687 - accuracy: 0.5126 - val_loss: 1.7276 - val_accuracy: 0.4258
# Epoch 3/10
# 12/12 [==============================] - 27s 2s/step - loss: 1.3874 - accuracy: 0.5293 - val_loss: 1.8814 - val_accuracy: 0.4023
# Epoch 4/10
# 12/12 [==============================] - 27s 2s/step - loss: 1.4064 - accuracy: 0.5126 - val_loss: 1.8413 - val_accuracy: 0.4023
# Epoch 5/10
# 12/12 [==============================] - 27s 2s/step - loss: 1.4034 - accuracy: 0.5126 - val_loss: 1.8998 - val_accuracy: 0.4180
# Epoch 6/10
# 12/12 [==============================] - 27s 2s/step - loss: 1.3704 - accuracy: 0.5196 - val_loss: 1.8350 - val_accuracy: 0.4102
# Epoch 7/10
# 12/12 [==============================] - 26s 2s/step - loss: 1.3926 - accuracy: 0.5293 - val_loss: 1.7916 - val_accuracy: 0.4062
# Epoch 8/10
#  5/12 [===========>..................] - ETA: 12s - loss: 1.3809 - accuracy: 0.5156
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22220\2799865396.py in <module>
# ----> 1 history = model_.fit(
#       2     train_generator,
#       3     steps_per_epoch=train_generator.n // train_generator.batch_size,
#       4     epochs=10,
#       5     validation_data=test_generator,
#
# e:\Ana\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# e:\Ana\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1648                         ):
#    1649                             callbacks.on_train_batch_begin(step)
# -> 1650                             tmp_logs = self.train_function(iterator)
#    1651                             if data_handler.should_sync:
#    1652                                 context.async_wait()
#
# e:\Ana\lib\site-packages\tensorflow\python\util\traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# e:\Ana\lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py in __call__(self, *args, **kwds)
#     878
#     879       with OptionalXlaContext(self._jit_compile):
# --> 880         result = self._call(*args, **kwds)
#     881
#     882       new_tracing_count = self.experimental_get_tracing_count()
#
# e:\Ana\lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py in _call(self, *args, **kwds)
#     910       # In this case we have created variables on the first call, so we run the
#     911       # defunned version which is guaranteed to never create variables.
# --> 912       return self._no_variable_creation_fn(*args, **kwds)  # pylint: disable=not-callable
#     913     elif self._variable_creation_fn is not None:
#     914       # Release the lock early so that multiple threads can perform the call
#
# e:\Ana\lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compiler.py in __call__(self, *args, **kwargs)
#     132       (concrete_function,
#     133        filtered_flat_args) = self._maybe_define_function(args, kwargs)
# --> 134     return concrete_function._call_flat(
#     135         filtered_flat_args, captured_inputs=concrete_function.captured_inputs)  # pylint: disable=protected-access
#     136
#
# e:\Ana\lib\site-packages\tensorflow\python\eager\polymorphic_function\monomorphic_function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1743         and executing_eagerly):
#    1744       # No tape is watching; skip to running the function.
# -> 1745       return self._build_call_outputs(self._inference_function.call(
#    1746           ctx, args, cancellation_manager=cancellation_manager))
#    1747     forward_backward = self._select_forward_and_backward_functions(
#
# e:\Ana\lib\site-packages\tensorflow\python\eager\polymorphic_function\monomorphic_function.py in call(self, ctx, args, cancellation_manager)
#     376       with _InterpolateFunctionError(self):
#     377         if cancellation_manager is None:
# --> 378           outputs = execute.execute(
#     379               str(self.signature.name),
#     380               num_outputs=self._num_outputs,
#
# e:\Ana\lib\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      50   try:
#      51     ctx.ensure_initialized()
# ---> 52     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      53                                         inputs, attrs, num_outputs)
#      54   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
history = model_.fit(
    train_generator,
    steps_per_epoch=train_generator.n // train_generator.batch_size,
    epochs=10,
    validation_data=test_generator,
    validation_steps=test_generator.n // test_generator.batch_size)
# Out:
# Epoch 1/10
# 12/12 [==============================] - ETA: 0s - loss: 2.4475 - accuracy: 0.1997
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22220\2799865396.py in <module>
# ----> 1 history = model_.fit(
#       2     train_generator,
#       3     steps_per_epoch=train_generator.n // train_generator.batch_size,
#       4     epochs=10,
#       5     validation_data=test_generator,
#
# e:\Ana\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# e:\Ana\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1692                             steps_per_execution=self._steps_per_execution,
#    1693                         )
# -> 1694                     val_logs = self.evaluate(
#    1695                         x=val_x,
#    1696                         y=val_y,
#
# e:\Ana\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# e:\Ana\lib\site-packages\keras\engine\training.py in evaluate(self, x, y, batch_size, verbose, sample_weight, steps, callbacks, max_queue_size, workers, use_multiprocessing, return_dict, **kwargs)
#    2038                         ):
#    2039                             callbacks.on_test_batch_begin(step)
# -> 2040                             tmp_logs = self.test_function(iterator)
#    2041                             if data_handler.should_sync:
#    2042                                 context.async_wait()
#
# e:\Ana\lib\site-packages\tensorflow\python\util\traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# e:\Ana\lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py in __call__(self, *args, **kwds)
#     878
#     879       with OptionalXlaContext(self._jit_compile):
# --> 880         result = self._call(*args, **kwds)
#     881
#     882       new_tracing_count = self.experimental_get_tracing_count()
#
# e:\Ana\lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py in _call(self, *args, **kwds)
#     926       # This is the first call of __call__, so we have to initialize.
#     927       initializers = []
# --> 928       self._initialize(args, kwds, add_initializers_to=initializers)
#     929     finally:
#     930       # At this point we know that the initialization is complete (or less
#
# e:\Ana\lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py in _initialize(self, args, kwds, add_initializers_to)
#     747     self._graph_deleter = FunctionDeleter(self._lifted_initializer_graph)
#     748     self._concrete_variable_creation_fn = (
# --> 749         self._variable_creation_fn    # pylint: disable=protected-access
#     750         ._get_concrete_function_internal_garbage_collected(
#     751             *args, **kwds))
#
# e:\Ana\lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compiler.py in _get_concrete_function_internal_garbage_collected(self, *args, **kwargs)
#     160     """Returns a concrete function which cleans up its graph function."""
#     161     with self._lock:
# --> 162       concrete_function, _ = self._maybe_define_concrete_function(args, kwargs)
#     163     return concrete_function
#     164
#
# e:\Ana\lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compiler.py in _maybe_define_concrete_function(self, args, kwargs)
#     155       kwargs = {}
#     156
# --> 157     return self._maybe_define_function(args, kwargs)
#     158
#     159   def _get_concrete_function_internal_garbage_collected(self, *args, **kwargs):
#
# e:\Ana\lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compiler.py in _maybe_define_function(self, args, kwargs)
#     358             args, kwargs = generalized_func_key._placeholder_value()  # pylint: disable=protected-access
#     359
# --> 360           concrete_function = self._create_concrete_function(args, kwargs)
#     361
#     362           graph_capture_container = concrete_function.graph._capture_func_lib  # pylint: disable=protected-access
#
# e:\Ana\lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compiler.py in _create_concrete_function(self, args, kwargs)
#     282     arg_names = base_arg_names + missing_arg_names
#     283     concrete_function = monomorphic_function.ConcreteFunction(
# --> 284         func_graph_module.func_graph_from_py_func(
#     285             self._name,
#     286             self._python_function,
#
# e:\Ana\lib\site-packages\tensorflow\python\framework\func_graph.py in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, acd_record_initial_resource_uses)
#    1281         _, original_func = tf_decorator.unwrap(python_func)
#    1282
# -> 1283       func_outputs = python_func(*func_args, **func_kwargs)
#    1284
#    1285       # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#
# e:\Ana\lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py in wrapped_fn(*args, **kwds)
#     643         # the function a weak reference to itself to avoid a reference cycle.
#     644         with OptionalXlaContext(compile_with_xla):
# --> 645           out = weak_wrapped_fn().__wrapped__(*args, **kwds)
#     646         return out
#     647
#
# e:\Ana\lib\site-packages\tensorflow\python\framework\func_graph.py in autograph_handler(*args, **kwargs)
#    1256           # TODO(mdan): Push this block higher in tf.function's call stack.
#    1257           try:
# -> 1258             return autograph.converted_call(
#    1259                 original_func,
#    1260                 args,
#
# e:\Ana\lib\site-packages\tensorflow\python\autograph\impl\api.py in converted_call(f, args, kwargs, caller_fn_scope, options)
#     437     try:
#     438       if kwargs is not None:
# --> 439         result = converted_f(*effective_args, **kwargs)
#     440       else:
#     441         result = converted_f(*effective_args)
#
# e:\Ana\lib\site-packages\keras\engine\training.py in tf__test_function(iterator)
#      13                 try:
#      14                     do_return = True
# ---> 15                     retval_ = ag__.converted_call(ag__.ld(step_function), (ag__.ld(self), ag__.ld(iterator)), None, fscope)
#      16                 except:
#      17                     do_return = False
#
# e:\Ana\lib\site-packages\tensorflow\python\autograph\impl\api.py in converted_call(f, args, kwargs, caller_fn_scope, options)
#     375
#     376   if not options.user_requested and conversion.is_allowlisted(f):
# --> 377     return _call_unconverted(f, args, kwargs, options)
#     378
#     379   # internal_convert_user_code is for example turned off when issuing a dynamic
#
# e:\Ana\lib\site-packages\tensorflow\python\autograph\impl\api.py in _call_unconverted(f, args, kwargs, options, update_cache)
#     457   if kwargs is not None:
#     458     return f(*args, **kwargs)
# --> 459   return f(*args)
#     460
#     461
#
# e:\Ana\lib\site-packages\keras\engine\training.py in step_function(model, iterator)
#    1802
#    1803             data = next(iterator)
# -> 1804             outputs = model.distribute_strategy.run(run_step, args=(data,))
#    1805             outputs = reduce_per_replica(
#    1806                 outputs,
#
# e:\Ana\lib\site-packages\tensorflow\python\distribute\distribute_lib.py in run(***failed resolving arguments***)
#    1314       fn = autograph.tf_convert(
#    1315           fn, autograph_ctx.control_status_ctx(), convert_by_default=False)
# -> 1316       return self._extended.call_for_each_replica(fn, args=args, kwargs=kwargs)
#    1317
#    1318   def reduce(self, reduce_op, value, axis):
#
# e:\Ana\lib\site-packages\tensorflow\python\distribute\distribute_lib.py in call_for_each_replica(self, fn, args, kwargs)
#    2893       kwargs = {}
#    2894     with self._container_strategy().scope():
# -> 2895       return self._call_for_each_replica(fn, args, kwargs)
#    2896
#    2897   def _call_for_each_replica(self, fn, args, kwargs):
#
# e:\Ana\lib\site-packages\tensorflow\python\distribute\distribute_lib.py in _call_for_each_replica(self, fn, args, kwargs)
#    3694   def _call_for_each_replica(self, fn, args, kwargs):
#    3695     with ReplicaContext(self._container_strategy(), replica_id_in_sync_group=0):
# -> 3696       return fn(*args, **kwargs)
#    3697
#    3698   def _reduce_to(self, reduce_op, value, destinations, options):
#
# e:\Ana\lib\site-packages\tensorflow\python\autograph\impl\api.py in wrapper(*args, **kwargs)
#     687       try:
#     688         with conversion_ctx:
# --> 689           return converted_call(f, args, kwargs, options=options)
#     690       except Exception as e:  # pylint:disable=broad-except
#     691         if hasattr(e, 'ag_error_metadata'):
#
# e:\Ana\lib\site-packages\tensorflow\python\autograph\impl\api.py in converted_call(f, args, kwargs, caller_fn_scope, options)
#     375
#     376   if not options.user_requested and conversion.is_allowlisted(f):
# --> 377     return _call_unconverted(f, args, kwargs, options)
#     378
#     379   # internal_convert_user_code is for example turned off when issuing a dynamic
#
# e:\Ana\lib\site-packages\tensorflow\python\autograph\impl\api.py in _call_unconverted(f, args, kwargs, options, update_cache)
#     456
#     457   if kwargs is not None:
# --> 458     return f(*args, **kwargs)
#     459   return f(*args)
#     460
#
# e:\Ana\lib\site-packages\keras\engine\training.py in run_step(data)
#    1790
#    1791             def run_step(data):
# -> 1792                 outputs = model.test_step(data)
#    1793                 # Ensure counter is updated only if `test_step` succeeds.
#    1794                 with tf.control_dependencies(_minimum_control_deps(outputs)):
#
# e:\Ana\lib\site-packages\keras\engine\training.py in test_step(self, data)
#    1754         x, y, sample_weight = data_adapter.unpack_x_y_sample_weight(data)
#    1755
# -> 1756         y_pred = self(x, training=False)
#    1757         # Updates stateful loss metrics.
#    1758         self.compute_loss(x, y, y_pred, sample_weight)
#
# e:\Ana\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# e:\Ana\lib\site-packages\keras\engine\training.py in __call__(self, *args, **kwargs)
#     559             layout_map_lib._map_subclass_model_variable(self, self._layout_map)
#     560
# --> 561         return super().__call__(*args, **kwargs)
#     562
#     563     @doc_controls.doc_in_current_and_subclasses
#
# e:\Ana\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# e:\Ana\lib\site-packages\keras\engine\base_layer.py in __call__(self, *args, **kwargs)
#    1130                     self._compute_dtype_object
#    1131                 ):
# -> 1132                     outputs = call_fn(inputs, *args, **kwargs)
#    1133
#    1134                 if self._activity_regularizer:
#
# e:\Ana\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      94         bound_signature = None
#      95         try:
# ---> 96             return fn(*args, **kwargs)
#      97         except Exception as e:
#      98             if hasattr(e, "_keras_call_info_injected"):
#
# e:\Ana\lib\site-packages\keras\engine\functional.py in call(self, inputs, training, mask)
#     509             a list of tensors if there are more than one outputs.
#     510         """
# --> 511         return self._run_internal_graph(inputs, training=training, mask=mask)
#     512
#     513     def compute_output_shape(self, input_shape):
#
# e:\Ana\lib\site-packages\keras\engine\functional.py in _run_internal_graph(self, inputs, training, mask)
#     666
#     667                 args, kwargs = node.map_arguments(tensor_dict)
# --> 668                 outputs = node.layer(*args, **kwargs)
#     669
#     670                 # Update tensor_dict.
#
# e:\Ana\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# e:\Ana\lib\site-packages\keras\engine\base_layer.py in __call__(self, *args, **kwargs)
#    1130                     self._compute_dtype_object
#    1131                 ):
# -> 1132                     outputs = call_fn(inputs, *args, **kwargs)
#    1133
#    1134                 if self._activity_regularizer:
#
# e:\Ana\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      94         bound_signature = None
#      95         try:
# ---> 96             return fn(*args, **kwargs)
#      97         except Exception as e:
#      98             if hasattr(e, "_keras_call_info_injected"):
#
# e:\Ana\lib\site-packages\keras\layers\core\activation.py in call(self, inputs)
#      57
#      58     def call(self, inputs):
# ---> 59         return self.activation(inputs)
#      60
#      61     def compute_output_shape(self, input_shape):
#
# e:\Ana\lib\site-packages\tensorflow\python\util\traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# e:\Ana\lib\site-packages\tensorflow\python\util\dispatch.py in op_dispatch_handler(*args, **kwargs)
#    1174       # Fallback dispatch system (dispatch v1):
#    1175       try:
# -> 1176         return dispatch_target(*args, **kwargs)
#    1177       except (TypeError, ValueError):
#    1178         # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# e:\Ana\lib\site-packages\keras\activations.py in relu(x, alpha, max_value, threshold)
#     315         Tensor will be of the same shape and dtype of input `x`.
#     316     """
# --> 317     return backend.relu(
#     318         x, alpha=alpha, max_value=max_value, threshold=threshold
#     319     )
#
# e:\Ana\lib\site-packages\tensorflow\python\util\traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# e:\Ana\lib\site-packages\tensorflow\python\util\dispatch.py in op_dispatch_handler(*args, **kwargs)
#    1174       # Fallback dispatch system (dispatch v1):
#    1175       try:
# -> 1176         return dispatch_target(*args, **kwargs)
#    1177       except (TypeError, ValueError):
#    1178         # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# e:\Ana\lib\site-packages\keras\backend.py in relu(x, alpha, max_value, threshold)
#    5367         clip_max = False
#    5368     else:
# -> 5369         x = tf.nn.relu(x)
#    5370
#    5371     if clip_max:
#
# e:\Ana\lib\site-packages\tensorflow\python\ops\gen_nn_ops.py in relu(features, name)
#   11370   # Add nodes to the TensorFlow graph.
#   11371   try:
# > 11372     _, _, _op, _outputs = _op_def_library._apply_op_helper(
#   11373         "Relu", features=features, name=name)
#   11374   except (TypeError, ValueError):
#
# e:\Ana\lib\site-packages\tensorflow\python\framework\op_def_library.py in _apply_op_helper(op_type_name, name, **keywords)
#     793       # Add Op to graph
#     794       # pylint: disable=protected-access
# --> 795       op = g._create_op_internal(op_type_name, inputs, dtypes=None,
#     796                                  name=scope, input_types=input_types,
#     797                                  attrs=attr_protos, op_def=op_def)
#
# e:\Ana\lib\site-packages\tensorflow\python\framework\func_graph.py in _create_op_internal(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_device)
#     747       inp = self.capture(inp)
#     748       captured_inputs.append(inp)
# --> 749     return super(FuncGraph, self)._create_op_internal(  # pylint: disable=protected-access
#     750         op_type, captured_inputs, dtypes, input_types, name, attrs, op_def,
#     751         compute_device)
#
# e:\Ana\lib\site-packages\tensorflow\python\framework\ops.py in _create_op_internal(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_device)
#    3796     # Session.run call cannot occur between creating and mutating the op.
#    3797     with self._mutation_lock():
# -> 3798       ret = Operation(
#    3799           node_def,
#    3800           self,
#
# e:\Ana\lib\site-packages\tensorflow\python\framework\ops.py in __init__(***failed resolving arguments***)
#    2104
#    2105     # Initialize c_op from node_def and other inputs
# -> 2106     c_op = _create_c_op(g, node_def, inputs, control_input_ops, op_def=op_def)
#    2107     self._init_from_c_op(c_op=c_op, g=g)
#    2108
#
# e:\Ana\lib\site-packages\tensorflow\python\util\traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# e:\Ana\lib\site-packages\tensorflow\python\framework\ops.py in _create_c_op(graph, node_def, inputs, control_inputs, op_def, extract_traceback)
#    1962
#    1963   try:
# -> 1964     c_op = pywrap_tf_session.TF_FinishOperation(op_desc)
#    1965   except errors.InvalidArgumentError as e:
#    1966     # Convert to ValueError for backwards compatibility.
#
# KeyboardInterrupt:
